# %% [markdown]
# ## Scrape Whoscored data

# %%
import pandas as pd
import numpy as np
import re
import json
import time
import pickle

from bs4 import BeautifulSoup as soup
from datetime import datetime as dt
from collections import OrderedDict
pd.options.mode.chained_assignment = None


try:
    from tqdm import trange
except ModuleNotFoundError:
    pass

from selenium import webdriver
from selenium.webdriver.common.by import By

# %% [markdown]
# ## Get league urls

# %%
main_url = "https://www.whoscored.com/"
def getLeagueUrls(league_count, minimize_window=True):
    """
    league_count: count of top "X" leagues
    minimize_window: minimizes the selenium webdriver window
    """

    driver = webdriver.Chrome('chromedriver.exe')

    if minimize_window:
            driver.minimize_window()

    driver.get(main_url)

    league_names = []
    league_urls = []

    for i in range(league_count):
            league_name = driver.find_element("xpath", '//*[@id="popular-tournaments-list"]/li['+str(i+1)+']/a').text
            league_link = driver.find_element("xpath", '//*[@id="popular-tournaments-list"]/li['+str(i+1)+']/a').get_attribute('href')

            league_names.append(league_name)
            league_urls.append(league_link)

    leagues = {}
    for name,link in zip(league_names,league_urls):
        leagues[name] = link

    driver.close()

    return leagues

# %%
leagues = getLeagueUrls(league_count = 5)
leagues
# Out:
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_87208/45423396.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')
# {'Premier League': 'https://www.whoscored.com/Regions/252/Tournaments/2/England-Premier-League',
#  'Serie A': 'https://www.whoscored.com/Regions/108/Tournaments/5/Italy-Serie-A',
#  'LaLiga': 'https://www.whoscored.com/Regions/206/Tournaments/4/Spain-LaLiga',
#  'Bundesliga': 'https://www.whoscored.com/Regions/81/Tournaments/3/Germany-Bundesliga',
#  'Ligue 1': 'https://www.whoscored.com/Regions/74/Tournaments/22/France-Ligue-1'}

# %% [markdown]
# ## Get match urls

# %%
def translateDate(data):
    """
    data: json data
    """

    for match in data:
        date = match['date'].split()
        match['date'] = ' '.join([TRANSLATE_DICT[date[0]], date[1], date[2]])

    return data


def getSortedData(data):

    try:
        data = sorted(data, key = lambda i: dt.strptime(i['date'], '%b %d %Y'))
        return data
    except ValueError:
        data = translateDate(data)
        data = sorted(data, key = lambda i: dt.strptime(i['date'], '%b %d %Y'))
        return data

# %%
def getFixtureData(driver):
    """
    driver: selenium webdriver
    """

    matches_ls = []
    table_rows = driver.find_elements(By.CLASS_NAME, 'divtable-row')
    for row in table_rows:
        match_dict = {}
        element = soup(row.get_attribute('innerHTML'))
        link_tag = element.find("a", {"class":"result-1 rc"})

        # Check type of link tag
        if type(link_tag) is type(None):
            date = row.text.split(', ')[-1]

        # if type(link_tag) is not type(None):
        else:
            match_dict['date'] = date
            match_dict['time'] = element.find('div', {'class':'col12-lg-1 col12-m-1 col12-s-0 col12-xs-0 time divtable-data'}).text
            match_dict['home'] = element.find_all("a", {"class":"team-link"})[0].text
            match_dict['away'] = element.find_all("a", {"class":"team-link"})[1].text
            match_dict['score'] = element.find("a", {"class":"result-1 rc"}).text
            match_dict['url'] = link_tag.get("href")

        # Append dictionary to matches
        matches_ls.append(match_dict)

    time.sleep(2)

    matches_ls = list(filter(None, matches_ls))

    return matches_ls

# %%
league_url = 'https://www.whoscored.com/Regions/206/Tournaments/4/Spain-LaLiga'

def getAllUrls(season:str):
    """
    season: enter season that you want. eg: "2022/23"
    """

    driver = webdriver.Chrome('chromedriver.exe')

    # Close webdriver window
    maximize_window = True
    if maximize_window:
        driver.maximize_window()

    # Get league url
    driver.get(league_url)
    time.sleep(5)

    # Get all seasons
    seasons = driver.find_element("xpath", '//*[@id="seasons"]').get_attribute('innerHTML').split(sep='\n')
    seasons = [i for i in seasons if i]

    # Select Specific season
    year = season
    for i in range(1, len(seasons)+1):
            if driver.find_element("xpath", '//*[@id="seasons"]/option['+str(i)+']').text == year:
                season = driver.find_element("xpath", '//*[@id="seasons"]/option['+str(i)+']').click()

    time.sleep(5)

    # Navigate to the fixtures page
    fixtures_page = driver.find_element("xpath", '//*[@id="link-fixtures"]')
    driver.execute_script("arguments[0].scrollIntoView();", fixtures_page)
    driver.execute_script("arguments[0].click();", fixtures_page)
    time.sleep(5)

    # Get month and store it in list
    months = []
    all_match_urls = []
    for i in range(12):
        month = driver.find_element("xpath", '//*[@id="date-config-toggle-button"]/span[1]').get_attribute('textContent')

        if month not in months:
            months.append(month)

            # Get match links
            match_urls = getFixtureData(driver=driver)

            # Get all urls
            for url in match_urls:
                if url not in all_match_urls:
                    all_match_urls.append(url)


            # Get previous month
            prev_month_btn = driver.find_element("xpath", '//*[@id="date-controller"]/a[1]').click()
            time.sleep(8)

        else:
            break

    return all_match_urls

# %%
all_match_urls = getAllUrls(season="2022/23")
# Out:
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_87208/1793678528.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')

# %%
all_match_urls
# Out:
# [{'date': 'Apr 1 2023',
#   'time': '13:00',
#   'home': 'Girona',
#   'away': 'Espanyol',
#   'score': '2 : 1',
#   'url': '/Matches/1650825/Live/Spain-LaLiga-2022-2023-Girona-Espanyol'},
#  {'date': 'Apr 1 2023',
#   'time': '15:15',
#   'home': 'Athletic Bilbao',
#   'away': 'Getafe',
#   'score': '0 : 0',
#   'url': '/Matches/1650819/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Getafe'},
#  {'date': 'Apr 1 2023',
#   'time': '17:30',
#   'home': 'Cadiz',
#   'away': 'Sevilla',
#   'score': '0 : 2',
#   'url': '/Matches/1650822/Live/Spain-LaLiga-2022-2023-Cadiz-Sevilla'},
#  {'date': 'Apr 1 2023',
#   'time': '20:00',
#   'home': 'Elche',
#   'away': 'Barcelona',
#   'score': '0 : 4',
#   'url': '/Matches/1650824/Live/Spain-LaLiga-2022-2023-Elche-Barcelona'},
#  {'date': 'Apr 2 2023',
#   'time': '13:00',
#   'home': 'Celta Vigo',
#   'away': 'Almeria',
#   'score': '2 : 2',
#   'url': '/Matches/1650828/Live/Spain-LaLiga-2022-2023-Celta-Vigo-Almeria'},
#  {'date': 'Apr 2 2023',
#   'time': '15:15',
#   'home': 'Real Madrid',
#   'away': 'Real Valladolid',
#   'score': '6 : 0',
#   'url': '/Matches/1650823/Live/Spain-LaLiga-2022-2023-Real-Madrid-Real-Valladolid'},
#  {'date': 'Apr 2 2023',
#   'time': '17:30',
#   'home': 'Villarreal',
#   'away': 'Real Sociedad',
#   'score': '2 : 0',
#   'url': '/Matches/1650826/Live/Spain-LaLiga-2022-2023-Villarreal-Real-Sociedad'},
#  {'date': 'Apr 2 2023',
#   'time': '20:00',
#   'home': 'Atletico Madrid',
#   'away': 'Real Betis',
#   'score': '1 : 0',
#   'url': '/Matches/1650820/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Real-Betis'},
#  {'date': 'Apr 3 2023',
#   'time': '20:00',
#   'home': 'Valencia',
#   'away': 'Rayo Vallecano',
#   'score': '1 : 1',
#   'url': '/Matches/1650827/Live/Spain-LaLiga-2022-2023-Valencia-Rayo-Vallecano'},
#  {'date': 'Apr 7 2023',
#   'time': '20:00',
#   'home': 'Sevilla',
#   'away': 'Celta Vigo',
#   'score': '2 : 2',
#   'url': '/Matches/1650835/Live/Spain-LaLiga-2022-2023-Sevilla-Celta-Vigo'},
#  {'date': 'Apr 8 2023',
#   'time': '13:00',
#   'home': 'Osasuna',
#   'away': 'Elche',
#   'score': '2 : 1',
#   'url': '/Matches/1650836/Live/Spain-LaLiga-2022-2023-Osasuna-Elche'},
#  {'date': 'Apr 8 2023',
#   'time': '15:15',
#   'home': 'Espanyol',
#   'away': 'Athletic Bilbao',
#   'score': '1 : 2',
#   'url': '/Matches/1650833/Live/Spain-LaLiga-2022-2023-Espanyol-Athletic-Bilbao'},
#  {'date': 'Apr 8 2023',
#   'time': '17:30',
#   'home': 'Real Sociedad',
#   'away': 'Getafe',
#   'score': '2 : 0',
#   'url': '/Matches/1650838/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Getafe'},
#  {'date': 'Apr 8 2023',
#   'time': '20:00',
#   'home': 'Real Madrid',
#   'away': 'Villarreal',
#   'score': '2 : 3',
#   'url': '/Matches/1650831/Live/Spain-LaLiga-2022-2023-Real-Madrid-Villarreal'},
#  {'date': 'Apr 9 2023',
#   'time': '13:00',
#   'home': 'Real Valladolid',
#   'away': 'Mallorca',
#   'score': '3 : 3',
#   'url': '/Matches/1650837/Live/Spain-LaLiga-2022-2023-Real-Valladolid-Mallorca'},
#  {'date': 'Apr 9 2023',
#   'time': '15:15',
#   'home': 'Real Betis',
#   'away': 'Cadiz',
#   'score': '0 : 2',
#   'url': '/Matches/1650830/Live/Spain-LaLiga-2022-2023-Real-Betis-Cadiz'},
#  {'date': 'Apr 9 2023',
#   'time': '17:30',
#   'home': 'Almeria',
#   'away': 'Valencia',
#   'score': '2 : 1',
#   'url': '/Matches/1650832/Live/Spain-LaLiga-2022-2023-Almeria-Valencia'},
#  {'date': 'Apr 9 2023',
#   'time': '20:00',
#   'home': 'Rayo Vallecano',
#   'away': 'Atletico Madrid',
#   'score': '1 : 2',
#   'url': '/Matches/1650834/Live/Spain-LaLiga-2022-2023-Rayo-Vallecano-Atletico-Madrid'},
#  {'date': 'Apr 10 2023',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Girona',
#   'score': '0 : 0',
#   'url': '/Matches/1650829/Live/Spain-LaLiga-2022-2023-Barcelona-Girona'},
#  {'date': 'Mar 3 2023',
#   'time': '20:00',
#   'home': 'Real Sociedad',
#   'away': 'Cadiz',
#   'score': '0 : 0',
#   'url': '/Matches/1650797/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Cadiz'},
#  {'date': 'Mar 4 2023',
#   'time': '13:00',
#   'home': 'Getafe',
#   'away': 'Girona',
#   'score': '3 : 2',
#   'url': '/Matches/1650792/Live/Spain-LaLiga-2022-2023-Getafe-Girona'},
#  {'date': 'Mar 4 2023',
#   'time': '15:15',
#   'home': 'Almeria',
#   'away': 'Villarreal',
#   'score': '0 : 2',
#   'url': '/Matches/1650793/Live/Spain-LaLiga-2022-2023-Almeria-Villarreal'},
#  {'date': 'Mar 4 2023',
#   'time': '17:30',
#   'home': 'Mallorca',
#   'away': 'Elche',
#   'score': '0 : 1',
#   'url': '/Matches/1650796/Live/Spain-LaLiga-2022-2023-Mallorca-Elche'},
#  {'date': 'Mar 4 2023',
#   'time': '20:00',
#   'home': 'Atletico Madrid',
#   'away': 'Sevilla',
#   'score': '6 : 1',
#   'url': '/Matches/1650789/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Sevilla'},
#  {'date': 'Mar 5 2023',
#   'time': '13:00',
#   'home': 'Real Valladolid',
#   'away': 'Espanyol',
#   'score': '2 : 1',
#   'url': '/Matches/1650798/Live/Spain-LaLiga-2022-2023-Real-Valladolid-Espanyol'},
#  {'date': 'Mar 5 2023',
#   'time': '15:15',
#   'home': 'Barcelona',
#   'away': 'Valencia',
#   'score': '1 : 0',
#   'url': '/Matches/1650790/Live/Spain-LaLiga-2022-2023-Barcelona-Valencia'},
#  {'date': 'Mar 5 2023',
#   'time': '17:30',
#   'home': 'Rayo Vallecano',
#   'away': 'Athletic Bilbao',
#   'score': '0 : 0',
#   'url': '/Matches/1650794/Live/Spain-LaLiga-2022-2023-Rayo-Vallecano-Athletic-Bilbao'},
#  {'date': 'Mar 5 2023',
#   'time': '20:00',
#   'home': 'Real Betis',
#   'away': 'Real Madrid',
#   'score': '0 : 0',
#   'url': '/Matches/1650791/Live/Spain-LaLiga-2022-2023-Real-Betis-Real-Madrid'},
#  {'date': 'Mar 6 2023',
#   'time': '20:00',
#   'home': 'Osasuna',
#   'away': 'Celta Vigo',
#   'score': '0 : 0',
#   'url': '/Matches/1650795/Live/Spain-LaLiga-2022-2023-Osasuna-Celta-Vigo'},
#  {'date': 'Mar 10 2023',
#   'time': '20:00',
#   'home': 'Cadiz',
#   'away': 'Getafe',
#   'score': '2 : 2',
#   'url': '/Matches/1650803/Live/Spain-LaLiga-2022-2023-Cadiz-Getafe'},
#  {'date': 'Mar 11 2023',
#   'time': '13:00',
#   'home': 'Real Madrid',
#   'away': 'Espanyol',
#   'score': '3 : 1',
#   'url': '/Matches/1650806/Live/Spain-LaLiga-2022-2023-Real-Madrid-Espanyol'},
#  {'date': 'Mar 11 2023',
#   'time': '15:15',
#   'home': 'Elche',
#   'away': 'Real Valladolid',
#   'score': '1 : 1',
#   'url': '/Matches/1650801/Live/Spain-LaLiga-2022-2023-Elche-Real-Valladolid'},
#  {'date': 'Mar 11 2023',
#   'time': '17:30',
#   'home': 'Celta Vigo',
#   'away': 'Rayo Vallecano',
#   'score': '3 : 0',
#   'url': '/Matches/1650800/Live/Spain-LaLiga-2022-2023-Celta-Vigo-Rayo-Vallecano'},
#  {'date': 'Mar 11 2023',
#   'time': '20:00',
#   'home': 'Valencia',
#   'away': 'Osasuna',
#   'score': '1 : 0',
#   'url': '/Matches/1650807/Live/Spain-LaLiga-2022-2023-Valencia-Osasuna'},
#  {'date': 'Mar 12 2023',
#   'time': '13:00',
#   'home': 'Mallorca',
#   'away': 'Real Sociedad',
#   'score': '1 : 1',
#   'url': '/Matches/1650802/Live/Spain-LaLiga-2022-2023-Mallorca-Real-Sociedad'},
#  {'date': 'Mar 12 2023',
#   'time': '15:15',
#   'home': 'Sevilla',
#   'away': 'Almeria',
#   'score': '2 : 1',
#   'url': '/Matches/1650808/Live/Spain-LaLiga-2022-2023-Sevilla-Almeria'},
#  {'date': 'Mar 12 2023',
#   'time': '17:30',
#   'home': 'Villarreal',
#   'away': 'Real Betis',
#   'score': '1 : 1',
#   'url': '/Matches/1650805/Live/Spain-LaLiga-2022-2023-Villarreal-Real-Betis'},
#  {'date': 'Mar 12 2023',
#   'time': '20:00',
#   'home': 'Athletic Bilbao',
#   'away': 'Barcelona',
#   'score': '0 : 1',
#   'url': '/Matches/1650799/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Barcelona'},
#  {'date': 'Mar 13 2023',
#   'time': '20:00',
#   'home': 'Girona',
#   'away': 'Atletico Madrid',
#   'score': '0 : 1',
#   'url': '/Matches/1650804/Live/Spain-LaLiga-2022-2023-Girona-Atletico-Madrid'},
#  {'date': 'Mar 17 2023',
#   'time': '20:00',
#   'home': 'Real Valladolid',
#   'away': 'Athletic Bilbao',
#   'score': '1 : 3',
#   'url': '/Matches/1650815/Live/Spain-LaLiga-2022-2023-Real-Valladolid-Athletic-Bilbao'},
#  {'date': 'Mar 18 2023',
#   'time': '13:00',
#   'home': 'Almeria',
#   'away': 'Cadiz',
#   'score': '1 : 1',
#   'url': '/Matches/1650814/Live/Spain-LaLiga-2022-2023-Almeria-Cadiz'},
#  {'date': 'Mar 18 2023',
#   'time': '15:15',
#   'home': 'Rayo Vallecano',
#   'away': 'Girona',
#   'score': '2 : 2',
#   'url': '/Matches/1650818/Live/Spain-LaLiga-2022-2023-Rayo-Vallecano-Girona'},
#  {'date': 'Mar 18 2023',
#   'time': '17:30',
#   'home': 'Espanyol',
#   'away': 'Celta Vigo',
#   'score': '1 : 3',
#   'url': '/Matches/1650816/Live/Spain-LaLiga-2022-2023-Espanyol-Celta-Vigo'},
#  {'date': 'Mar 18 2023',
#   'time': '20:00',
#   'home': 'Atletico Madrid',
#   'away': 'Valencia',
#   'score': '3 : 0',
#   'url': '/Matches/1650809/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Valencia'},
#  {'date': 'Mar 19 2023',
#   'time': '13:00',
#   'home': 'Real Betis',
#   'away': 'Mallorca',
#   'score': '1 : 0',
#   'url': '/Matches/1650811/Live/Spain-LaLiga-2022-2023-Real-Betis-Mallorca'},
#  {'date': 'Mar 19 2023',
#   'time': '15:15',
#   'home': 'Real Sociedad',
#   'away': 'Elche',
#   'score': '2 : 0',
#   'url': '/Matches/1650817/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Elche'},
#  {'date': 'Mar 19 2023',
#   'time': '15:15',
#   'home': 'Osasuna',
#   'away': 'Villarreal',
#   'score': '0 : 3',
#   'url': '/Matches/1650813/Live/Spain-LaLiga-2022-2023-Osasuna-Villarreal'},
#  {'date': 'Mar 19 2023',
#   'time': '17:30',
#   'home': 'Getafe',
#   'away': 'Sevilla',
#   'score': '2 : 0',
#   'url': '/Matches/1650812/Live/Spain-LaLiga-2022-2023-Getafe-Sevilla'},
#  {'date': 'Mar 19 2023',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Real Madrid',
#   'score': '2 : 1',
#   'url': '/Matches/1650810/Live/Spain-LaLiga-2022-2023-Barcelona-Real-Madrid'},
#  {'date': 'Mar 31 2023',
#   'time': '20:00',
#   'home': 'Mallorca',
#   'away': 'Osasuna',
#   'score': '0 : 0',
#   'url': '/Matches/1650821/Live/Spain-LaLiga-2022-2023-Mallorca-Osasuna'},
#  {'date': 'Feb 1 2023',
#   'time': '20:00',
#   'home': 'Real Betis',
#   'away': 'Barcelona',
#   'score': '1 : 2',
#   'url': '/Matches/1650725/Live/Spain-LaLiga-2022-2023-Real-Betis-Barcelona'},
#  {'date': 'Feb 2 2023',
#   'time': '20:00',
#   'home': 'Real Madrid',
#   'away': 'Valencia',
#   'score': '2 : 0',
#   'url': '/Matches/1650721/Live/Spain-LaLiga-2022-2023-Real-Madrid-Valencia'},
#  {'date': 'Feb 3 2023',
#   'time': '20:00',
#   'home': 'Athletic Bilbao',
#   'away': 'Cadiz',
#   'score': '4 : 1',
#   'url': '/Matches/1650749/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Cadiz'},
#  {'date': 'Feb 4 2023',
#   'time': '13:00',
#   'home': 'Espanyol',
#   'away': 'Osasuna',
#   'score': '1 : 1',
#   'url': '/Matches/1650755/Live/Spain-LaLiga-2022-2023-Espanyol-Osasuna'},
#  {'date': 'Feb 4 2023',
#   'time': '15:15',
#   'home': 'Elche',
#   'away': 'Villarreal',
#   'score': '3 : 1',
#   'url': '/Matches/1650753/Live/Spain-LaLiga-2022-2023-Elche-Villarreal'},
#  {'date': 'Feb 4 2023',
#   'time': '17:30',
#   'home': 'Atletico Madrid',
#   'away': 'Getafe',
#   'score': '1 : 1',
#   'url': '/Matches/1650750/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Getafe'},
#  {'date': 'Feb 4 2023',
#   'time': '20:00',
#   'home': 'Real Betis',
#   'away': 'Celta Vigo',
#   'score': '3 : 4',
#   'url': '/Matches/1650752/Live/Spain-LaLiga-2022-2023-Real-Betis-Celta-Vigo'},
#  {'date': 'Feb 5 2023',
#   'time': '13:00',
#   'home': 'Mallorca',
#   'away': 'Real Madrid',
#   'score': '1 : 0',
#   'url': '/Matches/1650754/Live/Spain-LaLiga-2022-2023-Mallorca-Real-Madrid'},
#  {'date': 'Feb 5 2023',
#   'time': '15:15',
#   'home': 'Girona',
#   'away': 'Valencia',
#   'score': '1 : 0',
#   'url': '/Matches/1650757/Live/Spain-LaLiga-2022-2023-Girona-Valencia'},
#  {'date': 'Feb 5 2023',
#   'time': '17:30',
#   'home': 'Real Sociedad',
#   'away': 'Real Valladolid',
#   'score': '0 : 1',
#   'url': '/Matches/1650756/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Real-Valladolid'},
#  {'date': 'Feb 5 2023',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Sevilla',
#   'score': '3 : 0',
#   'url': '/Matches/1650751/Live/Spain-LaLiga-2022-2023-Barcelona-Sevilla'},
#  {'date': 'Feb 6 2023',
#   'time': '20:00',
#   'home': 'Rayo Vallecano',
#   'away': 'Almeria',
#   'score': '2 : 0',
#   'url': '/Matches/1650758/Live/Spain-LaLiga-2022-2023-Rayo-Vallecano-Almeria'},
#  {'date': 'Feb 10 2023',
#   'time': '20:00',
#   'home': 'Cadiz',
#   'away': 'Girona',
#   'score': '2 : 0',
#   'url': '/Matches/1650760/Live/Spain-LaLiga-2022-2023-Cadiz-Girona'},
#  {'date': 'Feb 11 2023',
#   'time': '15:15',
#   'home': 'Almeria',
#   'away': 'Real Betis',
#   'score': '2 : 3',
#   'url': '/Matches/1650762/Live/Spain-LaLiga-2022-2023-Almeria-Real-Betis'},
#  {'date': 'Feb 11 2023',
#   'time': '17:30',
#   'home': 'Sevilla',
#   'away': 'Mallorca',
#   'score': '2 : 0',
#   'url': '/Matches/1650767/Live/Spain-LaLiga-2022-2023-Sevilla-Mallorca'},
#  {'date': 'Feb 11 2023',
#   'time': '20:00',
#   'home': 'Valencia',
#   'away': 'Athletic Bilbao',
#   'score': '1 : 2',
#   'url': '/Matches/1650763/Live/Spain-LaLiga-2022-2023-Valencia-Athletic-Bilbao'},
#  {'date': 'Feb 12 2023',
#   'time': '13:00',
#   'home': 'Getafe',
#   'away': 'Rayo Vallecano',
#   'score': '1 : 1',
#   'url': '/Matches/1650759/Live/Spain-LaLiga-2022-2023-Getafe-Rayo-Vallecano'},
#  {'date': 'Feb 12 2023',
#   'time': '15:15',
#   'home': 'Celta Vigo',
#   'away': 'Atletico Madrid',
#   'score': '0 : 1',
#   'url': '/Matches/1650764/Live/Spain-LaLiga-2022-2023-Celta-Vigo-Atletico-Madrid'},
#  {'date': 'Feb 12 2023',
#   'time': '17:30',
#   'home': 'Real Valladolid',
#   'away': 'Osasuna',
#   'score': '0 : 0',
#   'url': '/Matches/1650768/Live/Spain-LaLiga-2022-2023-Real-Valladolid-Osasuna'},
#  {'date': 'Feb 12 2023',
#   'time': '20:00',
#   'home': 'Villarreal',
#   'away': 'Barcelona',
#   'score': '0 : 1',
#   'url': '/Matches/1650765/Live/Spain-LaLiga-2022-2023-Villarreal-Barcelona'},
#  {'date': 'Feb 13 2023',
#   'time': '20:00',
#   'home': 'Espanyol',
#   'away': 'Real Sociedad',
#   'score': '2 : 3',
#   'url': '/Matches/1650761/Live/Spain-LaLiga-2022-2023-Espanyol-Real-Sociedad'},
#  {'date': 'Feb 15 2023',
#   'time': '20:00',
#   'home': 'Real Madrid',
#   'away': 'Elche',
#   'score': '4 : 0',
#   'url': '/Matches/1650766/Live/Spain-LaLiga-2022-2023-Real-Madrid-Elche'},
#  {'date': 'Feb 17 2023',
#   'time': '20:00',
#   'home': 'Girona',
#   'away': 'Almeria',
#   'score': '6 : 2',
#   'url': '/Matches/1650778/Live/Spain-LaLiga-2022-2023-Girona-Almeria'},
#  {'date': 'Feb 18 2023',
#   'time': '13:00',
#   'home': 'Real Sociedad',
#   'away': 'Celta Vigo',
#   'score': '1 : 1',
#   'url': '/Matches/1650777/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Celta-Vigo'},
#  {'date': 'Feb 18 2023',
#   'time': '15:15',
#   'home': 'Real Betis',
#   'away': 'Real Valladolid',
#   'score': '2 : 1',
#   'url': '/Matches/1650770/Live/Spain-LaLiga-2022-2023-Real-Betis-Real-Valladolid'},
#  {'date': 'Feb 18 2023',
#   'time': '17:30',
#   'home': 'Mallorca',
#   'away': 'Villarreal',
#   'score': '4 : 2',
#   'url': '/Matches/1650772/Live/Spain-LaLiga-2022-2023-Mallorca-Villarreal'},
#  {'date': 'Feb 18 2023',
#   'time': '20:00',
#   'home': 'Osasuna',
#   'away': 'Real Madrid',
#   'score': '0 : 2',
#   'url': '/Matches/1650774/Live/Spain-LaLiga-2022-2023-Osasuna-Real-Madrid'},
#  {'date': 'Feb 19 2023',
#   'time': '13:00',
#   'home': 'Elche',
#   'away': 'Espanyol',
#   'score': '0 : 1',
#   'url': '/Matches/1650771/Live/Spain-LaLiga-2022-2023-Elche-Espanyol'},
#  {'date': 'Feb 19 2023',
#   'time': '15:15',
#   'home': 'Rayo Vallecano',
#   'away': 'Sevilla',
#   'score': '1 : 1',
#   'url': '/Matches/1650775/Live/Spain-LaLiga-2022-2023-Rayo-Vallecano-Sevilla'},
#  {'date': 'Feb 19 2023',
#   'time': '17:30',
#   'home': 'Atletico Madrid',
#   'away': 'Athletic Bilbao',
#   'score': '1 : 0',
#   'url': '/Matches/1650776/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Athletic-Bilbao'},
#  {'date': 'Feb 19 2023',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Cadiz',
#   'score': '2 : 0',
#   'url': '/Matches/1650769/Live/Spain-LaLiga-2022-2023-Barcelona-Cadiz'},
#  {'date': 'Feb 20 2023',
#   'time': '20:00',
#   'home': 'Getafe',
#   'away': 'Valencia',
#   'score': '1 : 0',
#   'url': '/Matches/1650773/Live/Spain-LaLiga-2022-2023-Getafe-Valencia'},
#  {'date': 'Feb 24 2023',
#   'time': '20:00',
#   'home': 'Elche',
#   'away': 'Real Betis',
#   'score': '2 : 3',
#   'url': '/Matches/1650787/Live/Spain-LaLiga-2022-2023-Elche-Real-Betis'},
#  {'date': 'Feb 25 2023',
#   'time': '13:00',
#   'home': 'Espanyol',
#   'away': 'Mallorca',
#   'score': '2 : 1',
#   'url': '/Matches/1650784/Live/Spain-LaLiga-2022-2023-Espanyol-Mallorca'},
#  {'date': 'Feb 25 2023',
#   'time': '15:15',
#   'home': 'Cadiz',
#   'away': 'Rayo Vallecano',
#   'score': '1 : 0',
#   'url': '/Matches/1650783/Live/Spain-LaLiga-2022-2023-Cadiz-Rayo-Vallecano'},
#  {'date': 'Feb 25 2023',
#   'time': '17:30',
#   'home': 'Real Madrid',
#   'away': 'Atletico Madrid',
#   'score': '1 : 1',
#   'url': '/Matches/1650786/Live/Spain-LaLiga-2022-2023-Real-Madrid-Atletico-Madrid'},
#  {'date': 'Feb 25 2023',
#   'time': '20:00',
#   'home': 'Valencia',
#   'away': 'Real Sociedad',
#   'score': '1 : 0',
#   'url': '/Matches/1650780/Live/Spain-LaLiga-2022-2023-Valencia-Real-Sociedad'},
#  {'date': 'Feb 26 2023',
#   'time': '13:00',
#   'home': 'Athletic Bilbao',
#   'away': 'Girona',
#   'score': '2 : 3',
#   'url': '/Matches/1650781/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Girona'},
#  {'date': 'Feb 26 2023',
#   'time': '15:15',
#   'home': 'Celta Vigo',
#   'away': 'Real Valladolid',
#   'score': '3 : 0',
#   'url': '/Matches/1650782/Live/Spain-LaLiga-2022-2023-Celta-Vigo-Real-Valladolid'},
#  {'date': 'Feb 26 2023',
#   'time': '17:30',
#   'home': 'Almeria',
#   'away': 'Barcelona',
#   'score': '1 : 0',
#   'url': '/Matches/1650785/Live/Spain-LaLiga-2022-2023-Almeria-Barcelona'},
#  {'date': 'Feb 26 2023',
#   'time': '20:00',
#   'home': 'Sevilla',
#   'away': 'Osasuna',
#   'score': '2 : 3',
#   'url': '/Matches/1650779/Live/Spain-LaLiga-2022-2023-Sevilla-Osasuna'},
#  {'date': 'Feb 27 2023',
#   'time': '20:00',
#   'home': 'Villarreal',
#   'away': 'Getafe',
#   'score': '2 : 1',
#   'url': '/Matches/1650788/Live/Spain-LaLiga-2022-2023-Villarreal-Getafe'},
#  {'date': 'Jan 6 2023',
#   'time': '17:30',
#   'home': 'Elche',
#   'away': 'Celta Vigo',
#   'score': '0 : 1',
#   'url': '/Matches/1650715/Live/Spain-LaLiga-2022-2023-Elche-Celta-Vigo'},
#  {'date': 'Jan 6 2023',
#   'time': '20:00',
#   'home': 'Valencia',
#   'away': 'Cadiz',
#   'score': '0 : 1',
#   'url': '/Matches/1650717/Live/Spain-LaLiga-2022-2023-Valencia-Cadiz'},
#  {'date': 'Jan 7 2023',
#   'time': '15:15',
#   'home': 'Villarreal',
#   'away': 'Real Madrid',
#   'score': '2 : 1',
#   'url': '/Matches/1650718/Live/Spain-LaLiga-2022-2023-Villarreal-Real-Madrid'},
#  {'date': 'Jan 7 2023',
#   'time': '17:30',
#   'home': 'Mallorca',
#   'away': 'Real Valladolid',
#   'score': '1 : 0',
#   'url': '/Matches/1650711/Live/Spain-LaLiga-2022-2023-Mallorca-Real-Valladolid'},
#  {'date': 'Jan 7 2023',
#   'time': '20:00',
#   'home': 'Espanyol',
#   'away': 'Girona',
#   'score': '2 : 2',
#   'url': '/Matches/1650712/Live/Spain-LaLiga-2022-2023-Espanyol-Girona'},
#  {'date': 'Jan 8 2023',
#   'time': '13:00',
#   'home': 'Almeria',
#   'away': 'Real Sociedad',
#   'score': '0 : 2',
#   'url': '/Matches/1650713/Live/Spain-LaLiga-2022-2023-Almeria-Real-Sociedad'},
#  {'date': 'Jan 8 2023',
#   'time': '15:15',
#   'home': 'Rayo Vallecano',
#   'away': 'Real Betis',
#   'score': '1 : 2',
#   'url': '/Matches/1650714/Live/Spain-LaLiga-2022-2023-Rayo-Vallecano-Real-Betis'},
#  {'date': 'Jan 8 2023',
#   'time': '17:30',
#   'home': 'Sevilla',
#   'away': 'Getafe',
#   'score': '2 : 1',
#   'url': '/Matches/1650716/Live/Spain-LaLiga-2022-2023-Sevilla-Getafe'},
#  {'date': 'Jan 8 2023',
#   'time': '20:00',
#   'home': 'Atletico Madrid',
#   'away': 'Barcelona',
#   'score': '0 : 1',
#   'url': '/Matches/1650710/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Barcelona'},
#  {'date': 'Jan 9 2023',
#   'time': '20:00',
#   'home': 'Athletic Bilbao',
#   'away': 'Osasuna',
#   'score': '0 : 0',
#   'url': '/Matches/1650709/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Osasuna'},
#  {'date': 'Jan 13 2023',
#   'time': '20:00',
#   'home': 'Celta Vigo',
#   'away': 'Villarreal',
#   'score': '1 : 1',
#   'url': '/Matches/1650719/Live/Spain-LaLiga-2022-2023-Celta-Vigo-Villarreal'},
#  {'date': 'Jan 14 2023',
#   'time': '13:00',
#   'home': 'Real Valladolid',
#   'away': 'Rayo Vallecano',
#   'score': '0 : 1',
#   'url': '/Matches/1650728/Live/Spain-LaLiga-2022-2023-Real-Valladolid-Rayo-Vallecano'},
#  {'date': 'Jan 14 2023',
#   'time': '15:15',
#   'home': 'Girona',
#   'away': 'Sevilla',
#   'score': '2 : 1',
#   'url': '/Matches/1650723/Live/Spain-LaLiga-2022-2023-Girona-Sevilla'},
#  {'date': 'Jan 14 2023',
#   'time': '17:30',
#   'home': 'Osasuna',
#   'away': 'Mallorca',
#   'score': '1 : 0',
#   'url': '/Matches/1650726/Live/Spain-LaLiga-2022-2023-Osasuna-Mallorca'},
#  {'date': 'Jan 14 2023',
#   'time': '20:00',
#   'home': 'Real Sociedad',
#   'away': 'Athletic Bilbao',
#   'score': '3 : 1',
#   'url': '/Matches/1650724/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Athletic-Bilbao'},
#  {'date': 'Jan 15 2023',
#   'time': '13:00',
#   'home': 'Getafe',
#   'away': 'Espanyol',
#   'score': '1 : 2',
#   'url': '/Matches/1650727/Live/Spain-LaLiga-2022-2023-Getafe-Espanyol'},
#  {'date': 'Jan 15 2023',
#   'time': '15:15',
#   'home': 'Almeria',
#   'away': 'Atletico Madrid',
#   'score': '1 : 1',
#   'url': '/Matches/1650722/Live/Spain-LaLiga-2022-2023-Almeria-Atletico-Madrid'},
#  {'date': 'Jan 16 2023',
#   'time': '20:00',
#   'home': 'Cadiz',
#   'away': 'Elche',
#   'score': '1 : 1',
#   'url': '/Matches/1650720/Live/Spain-LaLiga-2022-2023-Cadiz-Elche'},
#  {'date': 'Jan 20 2023',
#   'time': '20:00',
#   'home': 'Mallorca',
#   'away': 'Celta Vigo',
#   'score': '1 : 0',
#   'url': '/Matches/1650735/Live/Spain-LaLiga-2022-2023-Mallorca-Celta-Vigo'},
#  {'date': 'Jan 21 2023',
#   'time': '13:00',
#   'home': 'Rayo Vallecano',
#   'away': 'Real Sociedad',
#   'score': '0 : 2',
#   'url': '/Matches/1650733/Live/Spain-LaLiga-2022-2023-Rayo-Vallecano-Real-Sociedad'},
#  {'date': 'Jan 21 2023',
#   'time': '15:15',
#   'home': 'Espanyol',
#   'away': 'Real Betis',
#   'score': '1 : 0',
#   'url': '/Matches/1650734/Live/Spain-LaLiga-2022-2023-Espanyol-Real-Betis'},
#  {'date': 'Jan 21 2023',
#   'time': '17:30',
#   'home': 'Atletico Madrid',
#   'away': 'Real Valladolid',
#   'score': '3 : 0',
#   'url': '/Matches/1650730/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Real-Valladolid'},
#  {'date': 'Jan 21 2023',
#   'time': '20:00',
#   'home': 'Sevilla',
#   'away': 'Cadiz',
#   'score': '1 : 0',
#   'url': '/Matches/1650736/Live/Spain-LaLiga-2022-2023-Sevilla-Cadiz'},
#  {'date': 'Jan 22 2023',
#   'time': '13:00',
#   'home': 'Villarreal',
#   'away': 'Girona',
#   'score': '1 : 0',
#   'url': '/Matches/1650738/Live/Spain-LaLiga-2022-2023-Villarreal-Girona'},
#  {'date': 'Jan 22 2023',
#   'time': '15:15',
#   'home': 'Elche',
#   'away': 'Osasuna',
#   'score': '1 : 1',
#   'url': '/Matches/1650732/Live/Spain-LaLiga-2022-2023-Elche-Osasuna'},
#  {'date': 'Jan 22 2023',
#   'time': '17:30',
#   'home': 'Barcelona',
#   'away': 'Getafe',
#   'score': '1 : 0',
#   'url': '/Matches/1650731/Live/Spain-LaLiga-2022-2023-Barcelona-Getafe'},
#  {'date': 'Jan 22 2023',
#   'time': '20:00',
#   'home': 'Athletic Bilbao',
#   'away': 'Real Madrid',
#   'score': '0 : 2',
#   'url': '/Matches/1650729/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Real-Madrid'},
#  {'date': 'Jan 23 2023',
#   'time': '20:00',
#   'home': 'Valencia',
#   'away': 'Almeria',
#   'score': '2 : 2',
#   'url': '/Matches/1650737/Live/Spain-LaLiga-2022-2023-Valencia-Almeria'},
#  {'date': 'Jan 27 2023',
#   'time': '20:00',
#   'home': 'Almeria',
#   'away': 'Espanyol',
#   'score': '3 : 1',
#   'url': '/Matches/1650741/Live/Spain-LaLiga-2022-2023-Almeria-Espanyol'},
#  {'date': 'Jan 28 2023',
#   'time': '13:00',
#   'home': 'Cadiz',
#   'away': 'Mallorca',
#   'score': '2 : 0',
#   'url': '/Matches/1650739/Live/Spain-LaLiga-2022-2023-Cadiz-Mallorca'},
#  {'date': 'Jan 28 2023',
#   'time': '15:15',
#   'home': 'Girona',
#   'away': 'Barcelona',
#   'score': '0 : 1',
#   'url': '/Matches/1650744/Live/Spain-LaLiga-2022-2023-Girona-Barcelona'},
#  {'date': 'Jan 28 2023',
#   'time': '17:30',
#   'home': 'Sevilla',
#   'away': 'Elche',
#   'score': '3 : 0',
#   'url': '/Matches/1650746/Live/Spain-LaLiga-2022-2023-Sevilla-Elche'},
#  {'date': 'Jan 28 2023',
#   'time': '20:00',
#   'home': 'Getafe',
#   'away': 'Real Betis',
#   'score': '0 : 1',
#   'url': '/Matches/1650745/Live/Spain-LaLiga-2022-2023-Getafe-Real-Betis'},
#  {'date': 'Jan 29 2023',
#   'time': '13:00',
#   'home': 'Real Valladolid',
#   'away': 'Valencia',
#   'score': '1 : 0',
#   'url': '/Matches/1650747/Live/Spain-LaLiga-2022-2023-Real-Valladolid-Valencia'},
#  {'date': 'Jan 29 2023',
#   'time': '15:15',
#   'home': 'Osasuna',
#   'away': 'Atletico Madrid',
#   'score': '0 : 1',
#   'url': '/Matches/1650743/Live/Spain-LaLiga-2022-2023-Osasuna-Atletico-Madrid'},
#  {'date': 'Jan 29 2023',
#   'time': '17:30',
#   'home': 'Celta Vigo',
#   'away': 'Athletic Bilbao',
#   'score': '1 : 0',
#   'url': '/Matches/1650742/Live/Spain-LaLiga-2022-2023-Celta-Vigo-Athletic-Bilbao'},
#  {'date': 'Jan 29 2023',
#   'time': '20:00',
#   'home': 'Real Madrid',
#   'away': 'Real Sociedad',
#   'score': '0 : 0',
#   'url': '/Matches/1650740/Live/Spain-LaLiga-2022-2023-Real-Madrid-Real-Sociedad'},
#  {'date': 'Jan 30 2023',
#   'time': '20:00',
#   'home': 'Villarreal',
#   'away': 'Rayo Vallecano',
#   'score': '0 : 1',
#   'url': '/Matches/1650748/Live/Spain-LaLiga-2022-2023-Villarreal-Rayo-Vallecano'},
#  {'date': 'Dec 29 2022',
#   'time': '16:00',
#   'home': 'Girona',
#   'away': 'Rayo Vallecano',
#   'score': '2 : 2',
#   'url': '/Matches/1650703/Live/Spain-LaLiga-2022-2023-Girona-Rayo-Vallecano'},
#  {'date': 'Dec 29 2022',
#   'time': '18:15',
#   'home': 'Real Betis',
#   'away': 'Athletic Bilbao',
#   'score': '0 : 0',
#   'url': '/Matches/1650704/Live/Spain-LaLiga-2022-2023-Real-Betis-Athletic-Bilbao'},
#  {'date': 'Dec 29 2022',
#   'time': '20:30',
#   'home': 'Atletico Madrid',
#   'away': 'Elche',
#   'score': '2 : 0',
#   'url': '/Matches/1650699/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Elche'},
#  {'date': 'Dec 30 2022',
#   'time': '16:00',
#   'home': 'Getafe',
#   'away': 'Mallorca',
#   'score': '2 : 0',
#   'url': '/Matches/1650702/Live/Spain-LaLiga-2022-2023-Getafe-Mallorca'},
#  {'date': 'Dec 30 2022',
#   'time': '18:15',
#   'home': 'Celta Vigo',
#   'away': 'Sevilla',
#   'score': '1 : 1',
#   'url': '/Matches/1650701/Live/Spain-LaLiga-2022-2023-Celta-Vigo-Sevilla'},
#  {'date': 'Dec 30 2022',
#   'time': '18:15',
#   'home': 'Cadiz',
#   'away': 'Almeria',
#   'score': '1 : 1',
#   'url': '/Matches/1650708/Live/Spain-LaLiga-2022-2023-Cadiz-Almeria'},
#  {'date': 'Dec 30 2022',
#   'time': '20:30',
#   'home': 'Real Valladolid',
#   'away': 'Real Madrid',
#   'score': '0 : 2',
#   'url': '/Matches/1650706/Live/Spain-LaLiga-2022-2023-Real-Valladolid-Real-Madrid'},
#  {'date': 'Dec 31 2022',
#   'time': '13:00',
#   'home': 'Barcelona',
#   'away': 'Espanyol',
#   'score': '1 : 1',
#   'url': '/Matches/1650700/Live/Spain-LaLiga-2022-2023-Barcelona-Espanyol'},
#  {'date': 'Dec 31 2022',
#   'time': '15:15',
#   'home': 'Villarreal',
#   'away': 'Valencia',
#   'score': '2 : 1',
#   'url': '/Matches/1650707/Live/Spain-LaLiga-2022-2023-Villarreal-Valencia'},
#  {'date': 'Dec 31 2022',
#   'time': '15:15',
#   'home': 'Real Sociedad',
#   'away': 'Osasuna',
#   'score': '2 : 0',
#   'url': '/Matches/1650705/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Osasuna'},
#  {'date': 'Nov 4 2022',
#   'time': '20:00',
#   'home': 'Girona',
#   'away': 'Athletic Bilbao',
#   'score': '2 : 1',
#   'url': '/Matches/1650684/Live/Spain-LaLiga-2022-2023-Girona-Athletic-Bilbao'},
#  {'date': 'Nov 5 2022',
#   'time': '13:00',
#   'home': 'Getafe',
#   'away': 'Cadiz',
#   'score': '0 : 0',
#   'url': '/Matches/1650687/Live/Spain-LaLiga-2022-2023-Getafe-Cadiz'},
#  {'date': 'Nov 5 2022',
#   'time': '15:15',
#   'home': 'Real Valladolid',
#   'away': 'Elche',
#   'score': '2 : 1',
#   'url': '/Matches/1650685/Live/Spain-LaLiga-2022-2023-Real-Valladolid-Elche'},
#  {'date': 'Nov 5 2022',
#   'time': '17:30',
#   'home': 'Celta Vigo',
#   'away': 'Osasuna',
#   'score': '1 : 2',
#   'url': '/Matches/1650681/Live/Spain-LaLiga-2022-2023-Celta-Vigo-Osasuna'},
#  {'date': 'Nov 5 2022',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Almeria',
#   'score': '2 : 0',
#   'url': '/Matches/1650688/Live/Spain-LaLiga-2022-2023-Barcelona-Almeria'},
#  {'date': 'Nov 6 2022',
#   'time': '13:00',
#   'home': 'Atletico Madrid',
#   'away': 'Espanyol',
#   'score': '1 : 1',
#   'url': '/Matches/1650679/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Espanyol'},
#  {'date': 'Nov 6 2022',
#   'time': '15:15',
#   'home': 'Real Sociedad',
#   'away': 'Valencia',
#   'score': '1 : 1',
#   'url': '/Matches/1650682/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Valencia'},
#  {'date': 'Nov 6 2022',
#   'time': '17:30',
#   'home': 'Villarreal',
#   'away': 'Mallorca',
#   'score': '0 : 2',
#   'url': '/Matches/1650686/Live/Spain-LaLiga-2022-2023-Villarreal-Mallorca'},
#  {'date': 'Nov 6 2022',
#   'time': '20:00',
#   'home': 'Real Betis',
#   'away': 'Sevilla',
#   'score': '1 : 1',
#   'url': '/Matches/1650680/Live/Spain-LaLiga-2022-2023-Real-Betis-Sevilla'},
#  {'date': 'Nov 7 2022',
#   'time': '20:00',
#   'home': 'Rayo Vallecano',
#   'away': 'Real Madrid',
#   'score': '3 : 2',
#   'url': '/Matches/1650683/Live/Spain-LaLiga-2022-2023-Rayo-Vallecano-Real-Madrid'},
#  {'date': 'Nov 8 2022',
#   'time': '18:00',
#   'home': 'Elche',
#   'away': 'Girona',
#   'score': '1 : 2',
#   'url': '/Matches/1650690/Live/Spain-LaLiga-2022-2023-Elche-Girona'},
#  {'date': 'Nov 8 2022',
#   'time': '19:00',
#   'home': 'Athletic Bilbao',
#   'away': 'Real Valladolid',
#   'score': '3 : 0',
#   'url': '/Matches/1650689/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Real-Valladolid'},
#  {'date': 'Nov 8 2022',
#   'time': '20:30',
#   'home': 'Osasuna',
#   'away': 'Barcelona',
#   'score': '1 : 2',
#   'url': '/Matches/1650694/Live/Spain-LaLiga-2022-2023-Osasuna-Barcelona'},
#  {'date': 'Nov 9 2022',
#   'time': '18:00',
#   'home': 'Almeria',
#   'away': 'Getafe',
#   'score': '1 : 0',
#   'url': '/Matches/1650692/Live/Spain-LaLiga-2022-2023-Almeria-Getafe'},
#  {'date': 'Nov 9 2022',
#   'time': '18:00',
#   'home': 'Sevilla',
#   'away': 'Real Sociedad',
#   'score': '1 : 2',
#   'url': '/Matches/1650698/Live/Spain-LaLiga-2022-2023-Sevilla-Real-Sociedad'},
#  {'date': 'Nov 9 2022',
#   'time': '19:00',
#   'home': 'Espanyol',
#   'away': 'Villarreal',
#   'score': '0 : 1',
#   'url': '/Matches/1650691/Live/Spain-LaLiga-2022-2023-Espanyol-Villarreal'},
#  {'date': 'Nov 9 2022',
#   'time': '20:30',
#   'home': 'Mallorca',
#   'away': 'Atletico Madrid',
#   'score': '1 : 0',
#   'url': '/Matches/1650693/Live/Spain-LaLiga-2022-2023-Mallorca-Atletico-Madrid'},
#  {'date': 'Nov 10 2022',
#   'time': '18:00',
#   'home': 'Rayo Vallecano',
#   'away': 'Celta Vigo',
#   'score': '0 : 0',
#   'url': '/Matches/1650696/Live/Spain-LaLiga-2022-2023-Rayo-Vallecano-Celta-Vigo'},
#  {'date': 'Nov 10 2022',
#   'time': '19:00',
#   'home': 'Valencia',
#   'away': 'Real Betis',
#   'score': '3 : 0',
#   'url': '/Matches/1650695/Live/Spain-LaLiga-2022-2023-Valencia-Real-Betis'},
#  {'date': 'Nov 10 2022',
#   'time': '20:30',
#   'home': 'Real Madrid',
#   'away': 'Cadiz',
#   'score': '2 : 1',
#   'url': '/Matches/1650697/Live/Spain-LaLiga-2022-2023-Real-Madrid-Cadiz'},
#  {'date': 'Oct 1 2022',
#   'time': '13:00',
#   'home': 'Cadiz',
#   'away': 'Villarreal',
#   'score': '0 : 0',
#   'url': '/Matches/1650610/Live/Spain-LaLiga-2022-2023-Cadiz-Villarreal'},
#  {'date': 'Oct 1 2022',
#   'time': '15:15',
#   'home': 'Getafe',
#   'away': 'Real Valladolid',
#   'score': '2 : 3',
#   'url': '/Matches/1650609/Live/Spain-LaLiga-2022-2023-Getafe-Real-Valladolid'},
#  {'date': 'Oct 1 2022',
#   'time': '17:30',
#   'home': 'Sevilla',
#   'away': 'Atletico Madrid',
#   'score': '0 : 2',
#   'url': '/Matches/1650613/Live/Spain-LaLiga-2022-2023-Sevilla-Atletico-Madrid'},
#  {'date': 'Oct 1 2022',
#   'time': '20:00',
#   'home': 'Mallorca',
#   'away': 'Barcelona',
#   'score': '0 : 1',
#   'url': '/Matches/1650614/Live/Spain-LaLiga-2022-2023-Mallorca-Barcelona'},
#  {'date': 'Oct 2 2022',
#   'time': '13:00',
#   'home': 'Espanyol',
#   'away': 'Valencia',
#   'score': '2 : 2',
#   'url': '/Matches/1650611/Live/Spain-LaLiga-2022-2023-Espanyol-Valencia'},
#  {'date': 'Oct 2 2022',
#   'time': '15:15',
#   'home': 'Celta Vigo',
#   'away': 'Real Betis',
#   'score': '1 : 0',
#   'url': '/Matches/1650615/Live/Spain-LaLiga-2022-2023-Celta-Vigo-Real-Betis'},
#  {'date': 'Oct 2 2022',
#   'time': '17:30',
#   'home': 'Girona',
#   'away': 'Real Sociedad',
#   'score': '3 : 5',
#   'url': '/Matches/1650612/Live/Spain-LaLiga-2022-2023-Girona-Real-Sociedad'},
#  {'date': 'Oct 2 2022',
#   'time': '20:00',
#   'home': 'Real Madrid',
#   'away': 'Osasuna',
#   'score': '1 : 1',
#   'url': '/Matches/1650617/Live/Spain-LaLiga-2022-2023-Real-Madrid-Osasuna'},
#  {'date': 'Oct 3 2022',
#   'time': '20:00',
#   'home': 'Rayo Vallecano',
#   'away': 'Elche',
#   'score': '2 : 1',
#   'url': '/Matches/1650616/Live/Spain-LaLiga-2022-2023-Rayo-Vallecano-Elche'},
#  {'date': 'Oct 7 2022',
#   'time': '20:00',
#   'home': 'Osasuna',
#   'away': 'Valencia',
#   'score': '1 : 2',
#   'url': '/Matches/1650624/Live/Spain-LaLiga-2022-2023-Osasuna-Valencia'},
#  {'date': 'Oct 8 2022',
#   'time': '13:00',
#   'home': 'Almeria',
#   'away': 'Rayo Vallecano',
#   'score': '3 : 1',
#   'url': '/Matches/1650626/Live/Spain-LaLiga-2022-2023-Almeria-Rayo-Vallecano'},
#  {'date': 'Oct 8 2022',
#   'time': '15:15',
#   'home': 'Atletico Madrid',
#   'away': 'Girona',
#   'score': '2 : 1',
#   'url': '/Matches/1650619/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Girona'},
#  {'date': 'Oct 8 2022',
#   'time': '17:30',
#   'home': 'Sevilla',
#   'away': 'Athletic Bilbao',
#   'score': '1 : 1',
#   'url': '/Matches/1650627/Live/Spain-LaLiga-2022-2023-Sevilla-Athletic-Bilbao'},
#  {'date': 'Oct 8 2022',
#   'time': '20:00',
#   'home': 'Getafe',
#   'away': 'Real Madrid',
#   'score': '0 : 1',
#   'url': '/Matches/1650622/Live/Spain-LaLiga-2022-2023-Getafe-Real-Madrid'},
#  {'date': 'Oct 9 2022',
#   'time': '13:00',
#   'home': 'Real Valladolid',
#   'away': 'Real Betis',
#   'score': '0 : 0',
#   'url': '/Matches/1650628/Live/Spain-LaLiga-2022-2023-Real-Valladolid-Real-Betis'},
#  {'date': 'Oct 9 2022',
#   'time': '15:15',
#   'home': 'Cadiz',
#   'away': 'Espanyol',
#   'score': '2 : 2',
#   'url': '/Matches/1650623/Live/Spain-LaLiga-2022-2023-Cadiz-Espanyol'},
#  {'date': 'Oct 9 2022',
#   'time': '17:30',
#   'home': 'Real Sociedad',
#   'away': 'Villarreal',
#   'score': '1 : 0',
#   'url': '/Matches/1650625/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Villarreal'},
#  {'date': 'Oct 9 2022',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Celta Vigo',
#   'score': '1 : 0',
#   'url': '/Matches/1650620/Live/Spain-LaLiga-2022-2023-Barcelona-Celta-Vigo'},
#  {'date': 'Oct 10 2022',
#   'time': '20:30',
#   'home': 'Elche',
#   'away': 'Mallorca',
#   'score': '1 : 1',
#   'url': '/Matches/1650621/Live/Spain-LaLiga-2022-2023-Elche-Mallorca'},
#  {'date': 'Oct 14 2022',
#   'time': '20:00',
#   'home': 'Rayo Vallecano',
#   'away': 'Getafe',
#   'score': '0 : 0',
#   'url': '/Matches/1650645/Live/Spain-LaLiga-2022-2023-Rayo-Vallecano-Getafe'},
#  {'date': 'Oct 15 2022',
#   'time': '13:00',
#   'home': 'Girona',
#   'away': 'Cadiz',
#   'score': '1 : 1',
#   'url': '/Matches/1650646/Live/Spain-LaLiga-2022-2023-Girona-Cadiz'},
#  {'date': 'Oct 15 2022',
#   'time': '15:15',
#   'home': 'Valencia',
#   'away': 'Elche',
#   'score': '2 : 2',
#   'url': '/Matches/1650644/Live/Spain-LaLiga-2022-2023-Valencia-Elche'},
#  {'date': 'Oct 15 2022',
#   'time': '17:30',
#   'home': 'Mallorca',
#   'away': 'Sevilla',
#   'score': '0 : 1',
#   'url': '/Matches/1650641/Live/Spain-LaLiga-2022-2023-Mallorca-Sevilla'},
#  {'date': 'Oct 15 2022',
#   'time': '20:00',
#   'home': 'Athletic Bilbao',
#   'away': 'Atletico Madrid',
#   'score': '0 : 1',
#   'url': '/Matches/1650639/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Atletico-Madrid'},
#  {'date': 'Oct 16 2022',
#   'time': '13:00',
#   'home': 'Celta Vigo',
#   'away': 'Real Sociedad',
#   'score': '1 : 2',
#   'url': '/Matches/1650640/Live/Spain-LaLiga-2022-2023-Celta-Vigo-Real-Sociedad'},
#  {'date': 'Oct 16 2022',
#   'time': '15:15',
#   'home': 'Real Madrid',
#   'away': 'Barcelona',
#   'score': '3 : 1',
#   'url': '/Matches/1650643/Live/Spain-LaLiga-2022-2023-Real-Madrid-Barcelona'},
#  {'date': 'Oct 16 2022',
#   'time': '17:30',
#   'home': 'Espanyol',
#   'away': 'Real Valladolid',
#   'score': '1 : 0',
#   'url': '/Matches/1650642/Live/Spain-LaLiga-2022-2023-Espanyol-Real-Valladolid'},
#  {'date': 'Oct 16 2022',
#   'time': '20:00',
#   'home': 'Real Betis',
#   'away': 'Almeria',
#   'score': '3 : 1',
#   'url': '/Matches/1650648/Live/Spain-LaLiga-2022-2023-Real-Betis-Almeria'},
#  {'date': 'Oct 17 2022',
#   'time': '20:00',
#   'home': 'Villarreal',
#   'away': 'Osasuna',
#   'score': '2 : 0',
#   'url': '/Matches/1650647/Live/Spain-LaLiga-2022-2023-Villarreal-Osasuna'},
#  {'date': 'Oct 18 2022',
#   'time': '18:00',
#   'home': 'Sevilla',
#   'away': 'Valencia',
#   'score': '1 : 1',
#   'url': '/Matches/1650652/Live/Spain-LaLiga-2022-2023-Sevilla-Valencia'},
#  {'date': 'Oct 18 2022',
#   'time': '19:00',
#   'home': 'Getafe',
#   'away': 'Athletic Bilbao',
#   'score': '2 : 2',
#   'url': '/Matches/1650654/Live/Spain-LaLiga-2022-2023-Getafe-Athletic-Bilbao'},
#  {'date': 'Oct 18 2022',
#   'time': '20:00',
#   'home': 'Atletico Madrid',
#   'away': 'Rayo Vallecano',
#   'score': '1 : 1',
#   'url': '/Matches/1650649/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Rayo-Vallecano'},
#  {'date': 'Oct 19 2022',
#   'time': '18:00',
#   'home': 'Cadiz',
#   'away': 'Real Betis',
#   'score': '0 : 0',
#   'url': '/Matches/1650655/Live/Spain-LaLiga-2022-2023-Cadiz-Real-Betis'},
#  {'date': 'Oct 19 2022',
#   'time': '18:00',
#   'home': 'Real Valladolid',
#   'away': 'Celta Vigo',
#   'score': '4 : 1',
#   'url': '/Matches/1650656/Live/Spain-LaLiga-2022-2023-Real-Valladolid-Celta-Vigo'},
#  {'date': 'Oct 19 2022',
#   'time': '19:00',
#   'home': 'Real Sociedad',
#   'away': 'Mallorca',
#   'score': '1 : 0',
#   'url': '/Matches/1650657/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Mallorca'},
#  {'date': 'Oct 19 2022',
#   'time': '20:00',
#   'home': 'Elche',
#   'away': 'Real Madrid',
#   'score': '0 : 3',
#   'url': '/Matches/1650651/Live/Spain-LaLiga-2022-2023-Elche-Real-Madrid'},
#  {'date': 'Oct 20 2022',
#   'time': '18:00',
#   'home': 'Almeria',
#   'away': 'Girona',
#   'score': '3 : 2',
#   'url': '/Matches/1650653/Live/Spain-LaLiga-2022-2023-Almeria-Girona'},
#  {'date': 'Oct 20 2022',
#   'time': '19:00',
#   'home': 'Osasuna',
#   'away': 'Espanyol',
#   'score': '1 : 0',
#   'url': '/Matches/1650658/Live/Spain-LaLiga-2022-2023-Osasuna-Espanyol'},
#  {'date': 'Oct 20 2022',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Villarreal',
#   'score': '3 : 0',
#   'url': '/Matches/1650650/Live/Spain-LaLiga-2022-2023-Barcelona-Villarreal'},
#  {'date': 'Oct 22 2022',
#   'time': '13:00',
#   'home': 'Rayo Vallecano',
#   'away': 'Cadiz',
#   'score': '5 : 1',
#   'url': '/Matches/1650666/Live/Spain-LaLiga-2022-2023-Rayo-Vallecano-Cadiz'},
#  {'date': 'Oct 22 2022',
#   'time': '15:15',
#   'home': 'Real Valladolid',
#   'away': 'Real Sociedad',
#   'score': '1 : 0',
#   'url': '/Matches/1650667/Live/Spain-LaLiga-2022-2023-Real-Valladolid-Real-Sociedad'},
#  {'date': 'Oct 22 2022',
#   'time': '17:30',
#   'home': 'Valencia',
#   'away': 'Mallorca',
#   'score': '1 : 2',
#   'url': '/Matches/1650665/Live/Spain-LaLiga-2022-2023-Valencia-Mallorca'},
#  {'date': 'Oct 22 2022',
#   'time': '20:00',
#   'home': 'Real Madrid',
#   'away': 'Sevilla',
#   'score': '3 : 1',
#   'url': '/Matches/1650660/Live/Spain-LaLiga-2022-2023-Real-Madrid-Sevilla'},
#  {'date': 'Oct 23 2022',
#   'time': '13:00',
#   'home': 'Espanyol',
#   'away': 'Elche',
#   'score': '2 : 2',
#   'url': '/Matches/1650664/Live/Spain-LaLiga-2022-2023-Espanyol-Elche'},
#  {'date': 'Oct 23 2022',
#   'time': '15:15',
#   'home': 'Real Betis',
#   'away': 'Atletico Madrid',
#   'score': '1 : 2',
#   'url': '/Matches/1650663/Live/Spain-LaLiga-2022-2023-Real-Betis-Atletico-Madrid'},
#  {'date': 'Oct 23 2022',
#   'time': '17:30',
#   'home': 'Girona',
#   'away': 'Osasuna',
#   'score': '1 : 1',
#   'url': '/Matches/1650661/Live/Spain-LaLiga-2022-2023-Girona-Osasuna'},
#  {'date': 'Oct 23 2022',
#   'time': '17:30',
#   'home': 'Villarreal',
#   'away': 'Almeria',
#   'score': '2 : 1',
#   'url': '/Matches/1650668/Live/Spain-LaLiga-2022-2023-Villarreal-Almeria'},
#  {'date': 'Oct 23 2022',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Athletic Bilbao',
#   'score': '4 : 0',
#   'url': '/Matches/1650662/Live/Spain-LaLiga-2022-2023-Barcelona-Athletic-Bilbao'},
#  {'date': 'Oct 24 2022',
#   'time': '20:00',
#   'home': 'Celta Vigo',
#   'away': 'Getafe',
#   'score': '1 : 1',
#   'url': '/Matches/1650659/Live/Spain-LaLiga-2022-2023-Celta-Vigo-Getafe'},
#  {'date': 'Oct 28 2022',
#   'time': '20:00',
#   'home': 'Mallorca',
#   'away': 'Espanyol',
#   'score': '1 : 1',
#   'url': '/Matches/1650676/Live/Spain-LaLiga-2022-2023-Mallorca-Espanyol'},
#  {'date': 'Oct 29 2022',
#   'time': '13:00',
#   'home': 'Almeria',
#   'away': 'Celta Vigo',
#   'score': '3 : 1',
#   'url': '/Matches/1650672/Live/Spain-LaLiga-2022-2023-Almeria-Celta-Vigo'},
#  {'date': 'Oct 29 2022',
#   'time': '15:15',
#   'home': 'Cadiz',
#   'away': 'Atletico Madrid',
#   'score': '3 : 2',
#   'url': '/Matches/1650673/Live/Spain-LaLiga-2022-2023-Cadiz-Atletico-Madrid'},
#  {'date': 'Oct 29 2022',
#   'time': '17:30',
#   'home': 'Sevilla',
#   'away': 'Rayo Vallecano',
#   'score': '0 : 1',
#   'url': '/Matches/1650677/Live/Spain-LaLiga-2022-2023-Sevilla-Rayo-Vallecano'},
#  {'date': 'Oct 29 2022',
#   'time': '20:00',
#   'home': 'Valencia',
#   'away': 'Barcelona',
#   'score': '0 : 1',
#   'url': '/Matches/1650674/Live/Spain-LaLiga-2022-2023-Valencia-Barcelona'},
#  {'date': 'Oct 30 2022',
#   'time': '13:00',
#   'home': 'Osasuna',
#   'away': 'Real Valladolid',
#   'score': '2 : 0',
#   'url': '/Matches/1650671/Live/Spain-LaLiga-2022-2023-Osasuna-Real-Valladolid'},
#  {'date': 'Oct 30 2022',
#   'time': '15:15',
#   'home': 'Real Madrid',
#   'away': 'Girona',
#   'score': '1 : 1',
#   'url': '/Matches/1650678/Live/Spain-LaLiga-2022-2023-Real-Madrid-Girona'},
#  {'date': 'Oct 30 2022',
#   'time': '17:30',
#   'home': 'Athletic Bilbao',
#   'away': 'Villarreal',
#   'score': '1 : 0',
#   'url': '/Matches/1650669/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Villarreal'},
#  {'date': 'Oct 30 2022',
#   'time': '20:00',
#   'home': 'Real Sociedad',
#   'away': 'Real Betis',
#   'score': '0 : 2',
#   'url': '/Matches/1650675/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Real-Betis'},
#  {'date': 'Oct 31 2022',
#   'time': '20:00',
#   'home': 'Elche',
#   'away': 'Getafe',
#   'score': '0 : 1',
#   'url': '/Matches/1650670/Live/Spain-LaLiga-2022-2023-Elche-Getafe'},
#  {'date': 'Sep 2 2022',
#   'time': '20:00',
#   'home': 'Celta Vigo',
#   'away': 'Cadiz',
#   'score': '3 : 0',
#   'url': '/Matches/1650586/Live/Spain-LaLiga-2022-2023-Celta-Vigo-Cadiz'},
#  {'date': 'Sep 3 2022',
#   'time': '13:00',
#   'home': 'Mallorca',
#   'away': 'Girona',
#   'score': '1 : 1',
#   'url': '/Matches/1650588/Live/Spain-LaLiga-2022-2023-Mallorca-Girona'},
#  {'date': 'Sep 3 2022',
#   'time': '15:15',
#   'home': 'Real Madrid',
#   'away': 'Real Betis',
#   'score': '2 : 1',
#   'url': '/Matches/1650583/Live/Spain-LaLiga-2022-2023-Real-Madrid-Real-Betis'},
#  {'date': 'Sep 3 2022',
#   'time': '17:30',
#   'home': 'Real Sociedad',
#   'away': 'Atletico Madrid',
#   'score': '1 : 1',
#   'url': '/Matches/1650581/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Atletico-Madrid'},
#  {'date': 'Sep 3 2022',
#   'time': '20:00',
#   'home': 'Sevilla',
#   'away': 'Barcelona',
#   'score': '0 : 3',
#   'url': '/Matches/1650582/Live/Spain-LaLiga-2022-2023-Sevilla-Barcelona'},
#  {'date': 'Sep 4 2022',
#   'time': '13:00',
#   'home': 'Osasuna',
#   'away': 'Rayo Vallecano',
#   'score': '2 : 1',
#   'url': '/Matches/1650580/Live/Spain-LaLiga-2022-2023-Osasuna-Rayo-Vallecano'},
#  {'date': 'Sep 4 2022',
#   'time': '15:15',
#   'home': 'Athletic Bilbao',
#   'away': 'Espanyol',
#   'score': '0 : 1',
#   'url': '/Matches/1650579/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Espanyol'},
#  {'date': 'Sep 4 2022',
#   'time': '17:30',
#   'home': 'Villarreal',
#   'away': 'Elche',
#   'score': '4 : 0',
#   'url': '/Matches/1650584/Live/Spain-LaLiga-2022-2023-Villarreal-Elche'},
#  {'date': 'Sep 4 2022',
#   'time': '20:00',
#   'home': 'Valencia',
#   'away': 'Getafe',
#   'score': '5 : 1',
#   'url': '/Matches/1650585/Live/Spain-LaLiga-2022-2023-Valencia-Getafe'},
#  {'date': 'Sep 5 2022',
#   'time': '20:00',
#   'home': 'Real Valladolid',
#   'away': 'Almeria',
#   'score': '1 : 0',
#   'url': '/Matches/1650587/Live/Spain-LaLiga-2022-2023-Real-Valladolid-Almeria'},
#  {'date': 'Sep 9 2022',
#   'time': '20:00',
#   'home': 'Girona',
#   'away': 'Real Valladolid',
#   'score': '2 : 1',
#   'url': '/Matches/1650595/Live/Spain-LaLiga-2022-2023-Girona-Real-Valladolid'},
#  {'date': 'Sep 10 2022',
#   'time': '13:00',
#   'home': 'Rayo Vallecano',
#   'away': 'Valencia',
#   'score': '2 : 1',
#   'url': '/Matches/1650593/Live/Spain-LaLiga-2022-2023-Rayo-Vallecano-Valencia'},
#  {'date': 'Sep 10 2022',
#   'time': '15:15',
#   'home': 'Espanyol',
#   'away': 'Sevilla',
#   'score': '2 : 3',
#   'url': '/Matches/1650592/Live/Spain-LaLiga-2022-2023-Espanyol-Sevilla'},
#  {'date': 'Sep 10 2022',
#   'time': '17:30',
#   'home': 'Cadiz',
#   'away': 'Barcelona',
#   'score': '0 : 4',
#   'url': '/Matches/1650597/Live/Spain-LaLiga-2022-2023-Cadiz-Barcelona'},
#  {'date': 'Sep 10 2022',
#   'time': '20:00',
#   'home': 'Atletico Madrid',
#   'away': 'Celta Vigo',
#   'score': '4 : 1',
#   'url': '/Matches/1650589/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Celta-Vigo'},
#  {'date': 'Sep 11 2022',
#   'time': '13:00',
#   'home': 'Real Madrid',
#   'away': 'Mallorca',
#   'score': '4 : 1',
#   'url': '/Matches/1650598/Live/Spain-LaLiga-2022-2023-Real-Madrid-Mallorca'},
#  {'date': 'Sep 11 2022',
#   'time': '15:15',
#   'home': 'Elche',
#   'away': 'Athletic Bilbao',
#   'score': '1 : 4',
#   'url': '/Matches/1650596/Live/Spain-LaLiga-2022-2023-Elche-Athletic-Bilbao'},
#  {'date': 'Sep 11 2022',
#   'time': '17:30',
#   'home': 'Getafe',
#   'away': 'Real Sociedad',
#   'score': '2 : 1',
#   'url': '/Matches/1650591/Live/Spain-LaLiga-2022-2023-Getafe-Real-Sociedad'},
#  {'date': 'Sep 11 2022',
#   'time': '20:00',
#   'home': 'Real Betis',
#   'away': 'Villarreal',
#   'score': '1 : 0',
#   'url': '/Matches/1650590/Live/Spain-LaLiga-2022-2023-Real-Betis-Villarreal'},
#  {'date': 'Sep 12 2022',
#   'time': '20:00',
#   'home': 'Almeria',
#   'away': 'Osasuna',
#   'score': '0 : 1',
#   'url': '/Matches/1650594/Live/Spain-LaLiga-2022-2023-Almeria-Osasuna'},
#  {'date': 'Sep 16 2022',
#   'time': '20:00',
#   'home': 'Real Valladolid',
#   'away': 'Cadiz',
#   'score': '0 : 1',
#   'url': '/Matches/1650604/Live/Spain-LaLiga-2022-2023-Real-Valladolid-Cadiz'},
#  {'date': 'Sep 17 2022',
#   'time': '13:00',
#   'home': 'Mallorca',
#   'away': 'Almeria',
#   'score': '1 : 0',
#   'url': '/Matches/1650607/Live/Spain-LaLiga-2022-2023-Mallorca-Almeria'},
#  {'date': 'Sep 17 2022',
#   'time': '15:15',
#   'home': 'Barcelona',
#   'away': 'Elche',
#   'score': '3 : 0',
#   'url': '/Matches/1650600/Live/Spain-LaLiga-2022-2023-Barcelona-Elche'},
#  {'date': 'Sep 17 2022',
#   'time': '17:30',
#   'home': 'Valencia',
#   'away': 'Celta Vigo',
#   'score': '3 : 0',
#   'url': '/Matches/1650602/Live/Spain-LaLiga-2022-2023-Valencia-Celta-Vigo'},
#  {'date': 'Sep 17 2022',
#   'time': '20:00',
#   'home': 'Athletic Bilbao',
#   'away': 'Rayo Vallecano',
#   'score': '3 : 2',
#   'url': '/Matches/1650599/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Rayo-Vallecano'},
#  {'date': 'Sep 18 2022',
#   'time': '13:00',
#   'home': 'Osasuna',
#   'away': 'Getafe',
#   'score': '0 : 2',
#   'url': '/Matches/1650603/Live/Spain-LaLiga-2022-2023-Osasuna-Getafe'},
#  {'date': 'Sep 18 2022',
#   'time': '15:15',
#   'home': 'Villarreal',
#   'away': 'Sevilla',
#   'score': '1 : 1',
#   'url': '/Matches/1650606/Live/Spain-LaLiga-2022-2023-Villarreal-Sevilla'},
#  {'date': 'Sep 18 2022',
#   'time': '17:30',
#   'home': 'Real Sociedad',
#   'away': 'Espanyol',
#   'score': '2 : 1',
#   'url': '/Matches/1650605/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Espanyol'},
#  {'date': 'Sep 18 2022',
#   'time': '17:30',
#   'home': 'Real Betis',
#   'away': 'Girona',
#   'score': '2 : 1',
#   'url': '/Matches/1650601/Live/Spain-LaLiga-2022-2023-Real-Betis-Girona'},
#  {'date': 'Sep 18 2022',
#   'time': '20:00',
#   'home': 'Atletico Madrid',
#   'away': 'Real Madrid',
#   'score': '1 : 2',
#   'url': '/Matches/1650608/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Real-Madrid'},
#  {'date': 'Sep 30 2022',
#   'time': '20:00',
#   'home': 'Athletic Bilbao',
#   'away': 'Almeria',
#   'score': '4 : 0',
#   'url': '/Matches/1650618/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Almeria'},
#  {'date': 'Aug 12 2022',
#   'time': '20:00',
#   'home': 'Osasuna',
#   'away': 'Sevilla',
#   'score': '2 : 1',
#   'url': '/Matches/1650634/Live/Spain-LaLiga-2022-2023-Osasuna-Sevilla'},
#  {'date': 'Aug 13 2022',
#   'time': '16:00',
#   'home': 'Celta Vigo',
#   'away': 'Espanyol',
#   'score': '2 : 2',
#   'url': '/Matches/1650632/Live/Spain-LaLiga-2022-2023-Celta-Vigo-Espanyol'},
#  {'date': 'Aug 13 2022',
#   'time': '18:00',
#   'home': 'Real Valladolid',
#   'away': 'Villarreal',
#   'score': '0 : 3',
#   'url': '/Matches/1650637/Live/Spain-LaLiga-2022-2023-Real-Valladolid-Villarreal'},
#  {'date': 'Aug 13 2022',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Rayo Vallecano',
#   'score': '0 : 0',
#   'url': '/Matches/1650630/Live/Spain-LaLiga-2022-2023-Barcelona-Rayo-Vallecano'},
#  {'date': 'Aug 14 2022',
#   'time': '16:30',
#   'home': 'Cadiz',
#   'away': 'Real Sociedad',
#   'score': '0 : 1',
#   'url': '/Matches/1650633/Live/Spain-LaLiga-2022-2023-Cadiz-Real-Sociedad'},
#  {'date': 'Aug 14 2022',
#   'time': '18:30',
#   'home': 'Valencia',
#   'away': 'Girona',
#   'score': '1 : 0',
#   'url': '/Matches/1650638/Live/Spain-LaLiga-2022-2023-Valencia-Girona'},
#  {'date': 'Aug 14 2022',
#   'time': '21:00',
#   'home': 'Almeria',
#   'away': 'Real Madrid',
#   'score': '1 : 2',
#   'url': '/Matches/1650635/Live/Spain-LaLiga-2022-2023-Almeria-Real-Madrid'},
#  {'date': 'Aug 15 2022',
#   'time': '16:30',
#   'home': 'Athletic Bilbao',
#   'away': 'Mallorca',
#   'score': '0 : 0',
#   'url': '/Matches/1650629/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Mallorca'},
#  {'date': 'Aug 15 2022',
#   'time': '18:30',
#   'home': 'Getafe',
#   'away': 'Atletico Madrid',
#   'score': '0 : 3',
#   'url': '/Matches/1650636/Live/Spain-LaLiga-2022-2023-Getafe-Atletico-Madrid'},
#  {'date': 'Aug 15 2022',
#   'time': '20:30',
#   'home': 'Real Betis',
#   'away': 'Elche',
#   'score': '3 : 0',
#   'url': '/Matches/1650631/Live/Spain-LaLiga-2022-2023-Real-Betis-Elche'},
#  {'date': 'Aug 19 2022',
#   'time': '19:00',
#   'home': 'Espanyol',
#   'away': 'Rayo Vallecano',
#   'score': '0 : 2',
#   'url': '/Matches/1650562/Live/Spain-LaLiga-2022-2023-Espanyol-Rayo-Vallecano'},
#  {'date': 'Aug 19 2022',
#   'time': '21:00',
#   'home': 'Sevilla',
#   'away': 'Real Valladolid',
#   'score': '1 : 1',
#   'url': '/Matches/1650563/Live/Spain-LaLiga-2022-2023-Sevilla-Real-Valladolid'},
#  {'date': 'Aug 20 2022',
#   'time': '16:30',
#   'home': 'Osasuna',
#   'away': 'Cadiz',
#   'score': '2 : 0',
#   'url': '/Matches/1650567/Live/Spain-LaLiga-2022-2023-Osasuna-Cadiz'},
#  {'date': 'Aug 20 2022',
#   'time': '18:30',
#   'home': 'Mallorca',
#   'away': 'Real Betis',
#   'score': '1 : 2',
#   'url': '/Matches/1650565/Live/Spain-LaLiga-2022-2023-Mallorca-Real-Betis'},
#  {'date': 'Aug 20 2022',
#   'time': '21:00',
#   'home': 'Celta Vigo',
#   'away': 'Real Madrid',
#   'score': '1 : 4',
#   'url': '/Matches/1650561/Live/Spain-LaLiga-2022-2023-Celta-Vigo-Real-Madrid'},
#  {'date': 'Aug 21 2022',
#   'time': '16:30',
#   'home': 'Athletic Bilbao',
#   'away': 'Valencia',
#   'score': '1 : 0',
#   'url': '/Matches/1650559/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Valencia'},
#  {'date': 'Aug 21 2022',
#   'time': '18:30',
#   'home': 'Atletico Madrid',
#   'away': 'Villarreal',
#   'score': '0 : 2',
#   'url': '/Matches/1650560/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Villarreal'},
#  {'date': 'Aug 21 2022',
#   'time': '21:00',
#   'home': 'Real Sociedad',
#   'away': 'Barcelona',
#   'score': '1 : 4',
#   'url': '/Matches/1650564/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Barcelona'},
#  {'date': 'Aug 22 2022',
#   'time': '19:00',
#   'home': 'Elche',
#   'away': 'Almeria',
#   'score': '1 : 1',
#   'url': '/Matches/1650568/Live/Spain-LaLiga-2022-2023-Elche-Almeria'},
#  {'date': 'Aug 22 2022',
#   'time': '21:00',
#   'home': 'Girona',
#   'away': 'Getafe',
#   'score': '3 : 1',
#   'url': '/Matches/1650566/Live/Spain-LaLiga-2022-2023-Girona-Getafe'},
#  {'date': 'Aug 26 2022',
#   'time': '19:00',
#   'home': 'Girona',
#   'away': 'Celta Vigo',
#   'score': '0 : 1',
#   'url': '/Matches/1650577/Live/Spain-LaLiga-2022-2023-Girona-Celta-Vigo'},
#  {'date': 'Aug 26 2022',
#   'time': '21:00',
#   'home': 'Real Betis',
#   'away': 'Osasuna',
#   'score': '1 : 0',
#   'url': '/Matches/1650570/Live/Spain-LaLiga-2022-2023-Real-Betis-Osasuna'},
#  {'date': 'Aug 27 2022',
#   'time': '16:30',
#   'home': 'Elche',
#   'away': 'Real Sociedad',
#   'score': '0 : 1',
#   'url': '/Matches/1650571/Live/Spain-LaLiga-2022-2023-Elche-Real-Sociedad'},
#  {'date': 'Aug 27 2022',
#   'time': '18:30',
#   'home': 'Rayo Vallecano',
#   'away': 'Mallorca',
#   'score': '0 : 2',
#   'url': '/Matches/1650578/Live/Spain-LaLiga-2022-2023-Rayo-Vallecano-Mallorca'},
#  {'date': 'Aug 27 2022',
#   'time': '21:00',
#   'home': 'Almeria',
#   'away': 'Sevilla',
#   'score': '2 : 1',
#   'url': '/Matches/1650574/Live/Spain-LaLiga-2022-2023-Almeria-Sevilla'},
#  {'date': 'Aug 28 2022',
#   'time': '16:30',
#   'home': 'Getafe',
#   'away': 'Villarreal',
#   'score': '0 : 0',
#   'url': '/Matches/1650572/Live/Spain-LaLiga-2022-2023-Getafe-Villarreal'},
#  {'date': 'Aug 28 2022',
#   'time': '18:30',
#   'home': 'Barcelona',
#   'away': 'Real Valladolid',
#   'score': '4 : 0',
#   'url': '/Matches/1650569/Live/Spain-LaLiga-2022-2023-Barcelona-Real-Valladolid'},
#  {'date': 'Aug 28 2022',
#   'time': '21:00',
#   'home': 'Espanyol',
#   'away': 'Real Madrid',
#   'score': '1 : 3',
#   'url': '/Matches/1650573/Live/Spain-LaLiga-2022-2023-Espanyol-Real-Madrid'},
#  {'date': 'Aug 29 2022',
#   'time': '19:00',
#   'home': 'Cadiz',
#   'away': 'Athletic Bilbao',
#   'score': '0 : 4',
#   'url': '/Matches/1650575/Live/Spain-LaLiga-2022-2023-Cadiz-Athletic-Bilbao'},
#  {'date': 'Aug 29 2022',
#   'time': '21:00',
#   'home': 'Valencia',
#   'away': 'Atletico Madrid',
#   'score': '0 : 1',
#   'url': '/Matches/1650576/Live/Spain-LaLiga-2022-2023-Valencia-Atletico-Madrid'}]

# %% [markdown]
# ## Get team urls

# %%
def getTeamUrls(team: str, data: list):
    """
    team: name of the team
    data: list of all json data
    """

    team_urls = []
    team = team
    for match in data:
        if match["home"] == team or match["away"] == team:
            team_urls.append(match)

    if team_urls:
        return team_urls
    else:
        print("Please check team name and try again :)")

# %%
team_urls = getTeamUrls(team = "Barcelona", data = all_match_urls)
team_urls
# Out:
# [{'date': 'Apr 1 2023',
#   'time': '20:00',
#   'home': 'Elche',
#   'away': 'Barcelona',
#   'score': '0 : 4',
#   'url': '/Matches/1650824/Live/Spain-LaLiga-2022-2023-Elche-Barcelona'},
#  {'date': 'Apr 10 2023',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Girona',
#   'score': '0 : 0',
#   'url': '/Matches/1650829/Live/Spain-LaLiga-2022-2023-Barcelona-Girona'},
#  {'date': 'Mar 5 2023',
#   'time': '15:15',
#   'home': 'Barcelona',
#   'away': 'Valencia',
#   'score': '1 : 0',
#   'url': '/Matches/1650790/Live/Spain-LaLiga-2022-2023-Barcelona-Valencia'},
#  {'date': 'Mar 12 2023',
#   'time': '20:00',
#   'home': 'Athletic Bilbao',
#   'away': 'Barcelona',
#   'score': '0 : 1',
#   'url': '/Matches/1650799/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Barcelona'},
#  {'date': 'Mar 19 2023',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Real Madrid',
#   'score': '2 : 1',
#   'url': '/Matches/1650810/Live/Spain-LaLiga-2022-2023-Barcelona-Real-Madrid'},
#  {'date': 'Feb 1 2023',
#   'time': '20:00',
#   'home': 'Real Betis',
#   'away': 'Barcelona',
#   'score': '1 : 2',
#   'url': '/Matches/1650725/Live/Spain-LaLiga-2022-2023-Real-Betis-Barcelona'},
#  {'date': 'Feb 5 2023',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Sevilla',
#   'score': '3 : 0',
#   'url': '/Matches/1650751/Live/Spain-LaLiga-2022-2023-Barcelona-Sevilla'},
#  {'date': 'Feb 12 2023',
#   'time': '20:00',
#   'home': 'Villarreal',
#   'away': 'Barcelona',
#   'score': '0 : 1',
#   'url': '/Matches/1650765/Live/Spain-LaLiga-2022-2023-Villarreal-Barcelona'},
#  {'date': 'Feb 19 2023',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Cadiz',
#   'score': '2 : 0',
#   'url': '/Matches/1650769/Live/Spain-LaLiga-2022-2023-Barcelona-Cadiz'},
#  {'date': 'Feb 26 2023',
#   'time': '17:30',
#   'home': 'Almeria',
#   'away': 'Barcelona',
#   'score': '1 : 0',
#   'url': '/Matches/1650785/Live/Spain-LaLiga-2022-2023-Almeria-Barcelona'},
#  {'date': 'Jan 8 2023',
#   'time': '20:00',
#   'home': 'Atletico Madrid',
#   'away': 'Barcelona',
#   'score': '0 : 1',
#   'url': '/Matches/1650710/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Barcelona'},
#  {'date': 'Jan 22 2023',
#   'time': '17:30',
#   'home': 'Barcelona',
#   'away': 'Getafe',
#   'score': '1 : 0',
#   'url': '/Matches/1650731/Live/Spain-LaLiga-2022-2023-Barcelona-Getafe'},
#  {'date': 'Jan 28 2023',
#   'time': '15:15',
#   'home': 'Girona',
#   'away': 'Barcelona',
#   'score': '0 : 1',
#   'url': '/Matches/1650744/Live/Spain-LaLiga-2022-2023-Girona-Barcelona'},
#  {'date': 'Dec 31 2022',
#   'time': '13:00',
#   'home': 'Barcelona',
#   'away': 'Espanyol',
#   'score': '1 : 1',
#   'url': '/Matches/1650700/Live/Spain-LaLiga-2022-2023-Barcelona-Espanyol'},
#  {'date': 'Nov 5 2022',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Almeria',
#   'score': '2 : 0',
#   'url': '/Matches/1650688/Live/Spain-LaLiga-2022-2023-Barcelona-Almeria'},
#  {'date': 'Nov 8 2022',
#   'time': '20:30',
#   'home': 'Osasuna',
#   'away': 'Barcelona',
#   'score': '1 : 2',
#   'url': '/Matches/1650694/Live/Spain-LaLiga-2022-2023-Osasuna-Barcelona'},
#  {'date': 'Oct 1 2022',
#   'time': '20:00',
#   'home': 'Mallorca',
#   'away': 'Barcelona',
#   'score': '0 : 1',
#   'url': '/Matches/1650614/Live/Spain-LaLiga-2022-2023-Mallorca-Barcelona'},
#  {'date': 'Oct 9 2022',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Celta Vigo',
#   'score': '1 : 0',
#   'url': '/Matches/1650620/Live/Spain-LaLiga-2022-2023-Barcelona-Celta-Vigo'},
#  {'date': 'Oct 16 2022',
#   'time': '15:15',
#   'home': 'Real Madrid',
#   'away': 'Barcelona',
#   'score': '3 : 1',
#   'url': '/Matches/1650643/Live/Spain-LaLiga-2022-2023-Real-Madrid-Barcelona'},
#  {'date': 'Oct 20 2022',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Villarreal',
#   'score': '3 : 0',
#   'url': '/Matches/1650650/Live/Spain-LaLiga-2022-2023-Barcelona-Villarreal'},
#  {'date': 'Oct 23 2022',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Athletic Bilbao',
#   'score': '4 : 0',
#   'url': '/Matches/1650662/Live/Spain-LaLiga-2022-2023-Barcelona-Athletic-Bilbao'},
#  {'date': 'Oct 29 2022',
#   'time': '20:00',
#   'home': 'Valencia',
#   'away': 'Barcelona',
#   'score': '0 : 1',
#   'url': '/Matches/1650674/Live/Spain-LaLiga-2022-2023-Valencia-Barcelona'},
#  {'date': 'Sep 3 2022',
#   'time': '20:00',
#   'home': 'Sevilla',
#   'away': 'Barcelona',
#   'score': '0 : 3',
#   'url': '/Matches/1650582/Live/Spain-LaLiga-2022-2023-Sevilla-Barcelona'},
#  {'date': 'Sep 10 2022',
#   'time': '17:30',
#   'home': 'Cadiz',
#   'away': 'Barcelona',
#   'score': '0 : 4',
#   'url': '/Matches/1650597/Live/Spain-LaLiga-2022-2023-Cadiz-Barcelona'},
#  {'date': 'Sep 17 2022',
#   'time': '15:15',
#   'home': 'Barcelona',
#   'away': 'Elche',
#   'score': '3 : 0',
#   'url': '/Matches/1650600/Live/Spain-LaLiga-2022-2023-Barcelona-Elche'},
#  {'date': 'Aug 13 2022',
#   'time': '20:00',
#   'home': 'Barcelona',
#   'away': 'Rayo Vallecano',
#   'score': '0 : 0',
#   'url': '/Matches/1650630/Live/Spain-LaLiga-2022-2023-Barcelona-Rayo-Vallecano'},
#  {'date': 'Aug 21 2022',
#   'time': '21:00',
#   'home': 'Real Sociedad',
#   'away': 'Barcelona',
#   'score': '1 : 4',
#   'url': '/Matches/1650564/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Barcelona'},
#  {'date': 'Aug 28 2022',
#   'time': '18:30',
#   'home': 'Barcelona',
#   'away': 'Real Valladolid',
#   'score': '4 : 0',
#   'url': '/Matches/1650569/Live/Spain-LaLiga-2022-2023-Barcelona-Real-Valladolid'}]

# %% [markdown]
# ## Get event data

# %%
def getMatchData(driver, url, display=True, close_window=True):
    driver.get(url)

    # get script data from page source
    script_content = driver.find_element("xpath", '//*[@id="layout-wrapper"]/script[1]').get_attribute('innerHTML')


    # clean script content
    script_content = re.sub(r"[\n\t]*", "", script_content)
    script_content = script_content[script_content.index("matchId"):script_content.rindex("}")]


    # this will give script content in list form
    script_content_list = list(filter(None, script_content.strip().split(',            ')))
    metadata = script_content_list.pop(1)


    # string format to json format
    match_data = json.loads(metadata[metadata.index('{'):])
    keys = [item[:item.index(':')].strip() for item in script_content_list]
    values = [item[item.index(':')+1:].strip() for item in script_content_list]
    for key,val in zip(keys, values):
        match_data[key] = json.loads(val)


    # get additional match details
    region = driver.find_element("xpath", '//*[@id="breadcrumb-nav"]/span[1]').text
    league = driver.find_element("xpath", '//*[@id="breadcrumb-nav"]/a').text.split(' - ')[0]
    season = driver.find_element("xpath", '//*[@id="breadcrumb-nav"]/a').text.split(' - ')[1]

    if len(driver.find_element("xpath", '//*[@id="breadcrumb-nav"]/a').text.split(' - ')) == 2:
        competition_type = 'League'
        competition_stage = ''

    elif len(driver.find_element("xpath", '//*[@id="breadcrumb-nav"]/a').text.split(' - ')) == 3:
        competition_type = 'Knock Out'
        competition_stage = driver.find_element("xpath", '//*[@id="breadcrumb-nav"]/a').text.split(' - ')[-1]

    else:
        print('Getting more than 3 types of information about the competition.')

    match_data['region'] = region
    match_data['league'] = league
    match_data['season'] = season
    match_data['competitionType'] = competition_type
    match_data['competitionStage'] = competition_stage


    # sort match_data dictionary alphabetically
    match_data = OrderedDict(sorted(match_data.items()))
    # match_data = dict(match_data)

    if display:
        print('Region: {}, League: {}, Season: {}, Match Id: {}'.format(region, league, season, match_data['matchId']))


    if close_window:
        driver.close()

    return match_data

# %%
# Get match links
links = []
for val in team_urls:
    if val["url"] not in links:
        links.append(val["url"])

links = [main_url[:-1]+i for i in links]
links
# Out:
# ['https://www.whoscored.com/Matches/1650824/Live/Spain-LaLiga-2022-2023-Elche-Barcelona',
#  'https://www.whoscored.com/Matches/1650829/Live/Spain-LaLiga-2022-2023-Barcelona-Girona',
#  'https://www.whoscored.com/Matches/1650790/Live/Spain-LaLiga-2022-2023-Barcelona-Valencia',
#  'https://www.whoscored.com/Matches/1650799/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Barcelona',
#  'https://www.whoscored.com/Matches/1650810/Live/Spain-LaLiga-2022-2023-Barcelona-Real-Madrid',
#  'https://www.whoscored.com/Matches/1650725/Live/Spain-LaLiga-2022-2023-Real-Betis-Barcelona',
#  'https://www.whoscored.com/Matches/1650751/Live/Spain-LaLiga-2022-2023-Barcelona-Sevilla',
#  'https://www.whoscored.com/Matches/1650765/Live/Spain-LaLiga-2022-2023-Villarreal-Barcelona',
#  'https://www.whoscored.com/Matches/1650769/Live/Spain-LaLiga-2022-2023-Barcelona-Cadiz',
#  'https://www.whoscored.com/Matches/1650785/Live/Spain-LaLiga-2022-2023-Almeria-Barcelona',
#  'https://www.whoscored.com/Matches/1650710/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Barcelona',
#  'https://www.whoscored.com/Matches/1650731/Live/Spain-LaLiga-2022-2023-Barcelona-Getafe',
#  'https://www.whoscored.com/Matches/1650744/Live/Spain-LaLiga-2022-2023-Girona-Barcelona',
#  'https://www.whoscored.com/Matches/1650700/Live/Spain-LaLiga-2022-2023-Barcelona-Espanyol',
#  'https://www.whoscored.com/Matches/1650688/Live/Spain-LaLiga-2022-2023-Barcelona-Almeria',
#  'https://www.whoscored.com/Matches/1650694/Live/Spain-LaLiga-2022-2023-Osasuna-Barcelona',
#  'https://www.whoscored.com/Matches/1650614/Live/Spain-LaLiga-2022-2023-Mallorca-Barcelona',
#  'https://www.whoscored.com/Matches/1650620/Live/Spain-LaLiga-2022-2023-Barcelona-Celta-Vigo',
#  'https://www.whoscored.com/Matches/1650643/Live/Spain-LaLiga-2022-2023-Real-Madrid-Barcelona',
#  'https://www.whoscored.com/Matches/1650650/Live/Spain-LaLiga-2022-2023-Barcelona-Villarreal',
#  'https://www.whoscored.com/Matches/1650662/Live/Spain-LaLiga-2022-2023-Barcelona-Athletic-Bilbao',
#  'https://www.whoscored.com/Matches/1650674/Live/Spain-LaLiga-2022-2023-Valencia-Barcelona',
#  'https://www.whoscored.com/Matches/1650582/Live/Spain-LaLiga-2022-2023-Sevilla-Barcelona',
#  'https://www.whoscored.com/Matches/1650597/Live/Spain-LaLiga-2022-2023-Cadiz-Barcelona',
#  'https://www.whoscored.com/Matches/1650600/Live/Spain-LaLiga-2022-2023-Barcelona-Elche',
#  'https://www.whoscored.com/Matches/1650630/Live/Spain-LaLiga-2022-2023-Barcelona-Rayo-Vallecano',
#  'https://www.whoscored.com/Matches/1650564/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Barcelona',
#  'https://www.whoscored.com/Matches/1650569/Live/Spain-LaLiga-2022-2023-Barcelona-Real-Valladolid']

# %%
with open("event-data-2023-04-11 20:57:50.511532.pkl", "rb") as f:
    event_data = pickle.load(f)

    for link in links:
        print(link)
# Out:
# https://www.whoscored.com/Matches/1650824/Live/Spain-LaLiga-2022-2023-Elche-Barcelona
# https://www.whoscored.com/Matches/1650829/Live/Spain-LaLiga-2022-2023-Barcelona-Girona
# https://www.whoscored.com/Matches/1650790/Live/Spain-LaLiga-2022-2023-Barcelona-Valencia
# https://www.whoscored.com/Matches/1650799/Live/Spain-LaLiga-2022-2023-Athletic-Bilbao-Barcelona
# https://www.whoscored.com/Matches/1650810/Live/Spain-LaLiga-2022-2023-Barcelona-Real-Madrid
# https://www.whoscored.com/Matches/1650725/Live/Spain-LaLiga-2022-2023-Real-Betis-Barcelona
# https://www.whoscored.com/Matches/1650751/Live/Spain-LaLiga-2022-2023-Barcelona-Sevilla
# https://www.whoscored.com/Matches/1650765/Live/Spain-LaLiga-2022-2023-Villarreal-Barcelona
# https://www.whoscored.com/Matches/1650769/Live/Spain-LaLiga-2022-2023-Barcelona-Cadiz
# https://www.whoscored.com/Matches/1650785/Live/Spain-LaLiga-2022-2023-Almeria-Barcelona
# https://www.whoscored.com/Matches/1650710/Live/Spain-LaLiga-2022-2023-Atletico-Madrid-Barcelona
# https://www.whoscored.com/Matches/1650731/Live/Spain-LaLiga-2022-2023-Barcelona-Getafe
# https://www.whoscored.com/Matches/1650744/Live/Spain-LaLiga-2022-2023-Girona-Barcelona
# https://www.whoscored.com/Matches/1650700/Live/Spain-LaLiga-2022-2023-Barcelona-Espanyol
# https://www.whoscored.com/Matches/1650688/Live/Spain-LaLiga-2022-2023-Barcelona-Almeria
# https://www.whoscored.com/Matches/1650694/Live/Spain-LaLiga-2022-2023-Osasuna-Barcelona
# https://www.whoscored.com/Matches/1650614/Live/Spain-LaLiga-2022-2023-Mallorca-Barcelona
# https://www.whoscored.com/Matches/1650620/Live/Spain-LaLiga-2022-2023-Barcelona-Celta-Vigo
# https://www.whoscored.com/Matches/1650643/Live/Spain-LaLiga-2022-2023-Real-Madrid-Barcelona
# https://www.whoscored.com/Matches/1650650/Live/Spain-LaLiga-2022-2023-Barcelona-Villarreal
# https://www.whoscored.com/Matches/1650662/Live/Spain-LaLiga-2022-2023-Barcelona-Athletic-Bilbao
# https://www.whoscored.com/Matches/1650674/Live/Spain-LaLiga-2022-2023-Valencia-Barcelona
# https://www.whoscored.com/Matches/1650582/Live/Spain-LaLiga-2022-2023-Sevilla-Barcelona
# https://www.whoscored.com/Matches/1650597/Live/Spain-LaLiga-2022-2023-Cadiz-Barcelona
# https://www.whoscored.com/Matches/1650600/Live/Spain-LaLiga-2022-2023-Barcelona-Elche
# https://www.whoscored.com/Matches/1650630/Live/Spain-LaLiga-2022-2023-Barcelona-Rayo-Vallecano
# https://www.whoscored.com/Matches/1650564/Live/Spain-LaLiga-2022-2023-Real-Sociedad-Barcelona
# https://www.whoscored.com/Matches/1650569/Live/Spain-LaLiga-2022-2023-Barcelona-Real-Valladolid

# %%
# Get event data

with open("event-data-2023-04-11 20:57:50.511532.pkl", "rb") as f:
    event_data = pickle.load(f)


    count = len(links)
    data_crawl = False

    for link in links:

        match_id = re.findall(r'\d+', link)[0]
        count -= 1

        if match_id not in event_data.keys():
            # Scrape data
            driver = webdriver.Chrome('chromedriver.exe')
            data = getMatchData(driver = driver, url = link)

            # Convert collections to dictionary
            event_data[match_id] = dict(data)


            # Cache most recent crawl using timestamp
            if count == 0:

                print("----------- All matches scraped -----------")

                timestamp = dt.now()

                with open(f"event-data-{timestamp}.pkl", "wb")  as f:
                    pickle.dump(event_data, f)

            time.sleep(10)

        else:
            data_crawl = True

    if data_crawl == True:
        print("All data has been obtained!")
# Out:
# All data has been obtained!

# %% [markdown]
# ## Create event data

# %%
def createEventsDF(data):

    events = data['events']
    for event in events:
        event.update({'matchId' : data['matchId'],
                     'startDate' : data['startDate'],
                     'startTime' : data['startTime'],
                     'score' : data['score'],
                     'ftScore' : data['ftScore'],
                     'htScore' : data['htScore'],
                     'etScore' : data['etScore'],
                     'venueName' : data['venueName'],
                     'maxMinute' : data['maxMinute']})
    events_df = pd.DataFrame(events)


    # clean period column
    events_df['period'] = pd.json_normalize(events_df['period'])['displayName']

    # clean type column
    events_df['type'] = pd.json_normalize(events_df['type'])['displayName']

    # clean outcomeType column
    events_df['outcomeType'] = pd.json_normalize(events_df['outcomeType'])['displayName']

    # clean outcomeType column
    try:
        x = events_df['cardType'].fillna({i: {} for i in events_df.index})
        events_df['cardType'] = pd.json_normalize(x)['displayName'].fillna(False)
    except KeyError:
        events_df['cardType'] = False

    # clean satisfiedEventTypes column
    eventTypeDict = data['matchCentreEventTypeJson']
    for i in range(len(events_df)):
        row = events_df.loc[i, 'satisfiedEventsTypes'].copy()
        events_df['satisfiedEventsTypes'].loc[i] = [list(eventTypeDict.keys())[list(eventTypeDict.values()).index(event)] for event in row]

    # clean qualifiers column
    try:
        for i in events_df.index:
            row = events_df.loc[i, 'qualifiers'].copy()
            if len(row) != 0:
                for irow in range(len(row)):
                    row[irow]['type'] = row[irow]['type']['displayName']
    except TypeError:
        pass

    # clean isShot column
    if 'isShot' in events_df.columns:
        events_df['isShot'] = events_df['isShot'].replace(np.nan, False)
    else:
        events_df['isShot'] = False

    # clean isGoal column
    if 'isGoal' in events_df.columns:
        events_df['isGoal'] = events_df['isGoal'].replace(np.nan, False)
    else:
        events_df['isGoal'] = False

    # add player name column
    events_df.loc[events_df.playerId.notna(), 'playerId'] = events_df.loc[events_df.playerId.notna(), 'playerId'].astype(int).astype(str)
    player_name_col = events_df.loc[:, 'playerId'].map(data['playerIdNameDictionary'])
    events_df.insert(loc=events_df.columns.get_loc("playerId")+1, column='playerName', value=player_name_col)

    # add home/away column
    h_a_col = events_df['teamId'].map({data['home']['teamId']:'h', data['away']['teamId']:'a'})
    events_df.insert(loc=events_df.columns.get_loc("teamId")+1, column='h_a', value=h_a_col)

    # adding shot body part column
    events_df['shotBodyType'] =  np.nan
    for i in events_df.loc[events_df.isShot==True].index:
        for j in events_df.loc[events_df.isShot==True].qualifiers.loc[i]:
            if j['type'] == 'RightFoot' or j['type'] == 'LeftFoot' or j['type'] == 'Head' or j['type'] == 'OtherBodyPart':
                events_df['shotBodyType'].loc[i] = j['type']

    # adding shot situation column
    events_df['situation'] =  np.nan
    for i in events_df.loc[events_df.isShot==True].index:
        for j in events_df.loc[events_df.isShot==True].qualifiers.loc[i]:
            if j['type'] == 'FromCorner' or j['type'] == 'SetPiece' or j['type'] == 'DirectFreekick':
                events_df['situation'].loc[i] = j['type']
            if j['type'] == 'RegularPlay':
                events_df['situation'].loc[i] = 'OpenPlay'

    # adding other event types columns
    event_types = list(data['matchCentreEventTypeJson'].keys())
    for event_type in event_types:
        events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])

    return events_df

# %%
# Get final dataframe
match_id_list = []
df_final = pd.DataFrame()

for key,val in event_data.items():

    if key not in match_id_list:
        df = createEventsDF(event_data[key])
        df_final = pd.concat([df_final, df]).reset_index(drop = True)

        match_id_list.append(key)

# Add scraped match ids to pickle file
with open('match_ids.pkl', 'wb') as f:
    pickle.dump(match_id_list, f)
# Out:
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])
# /var/folders/h7/zl8j3kvn5vl_xpmf_mnnfxm80000gn/T/ipykernel_63162/859461418.py:89: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   events_df[event_type] = pd.Series([event_type in row for row in list(events_df['satisfiedEventsTypes'])])

# %% [markdown]
# ## Save dataframe

# %%
def saveDF(prompt:"no"):

    if prompt.upper() == "YES":
        df_final.to_pickle("./barca.pkl")

    elif prompt.upper() == "NO":
        pass

    else:
        print("Please provide YES/NO prompt only.")

# saveDF(prompt="yes")
